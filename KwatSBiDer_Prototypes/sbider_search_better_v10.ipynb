# %%
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import collections
import weakref

# %%
class node(object):
    def __init__(self, value):
        self.value = value
        ###print "node.__init__(self, value): self, value:", value, type(value)
        self.children = []
        self.parent = None
    
    def __repr__(self, level=0):
        ret = "\t"*level+repr(self.value)+"\n"
        for child in self.children:
            ret += child.__repr__(level+1)
        return ret
    
    def append_child(self, obj):
        ###print "append_child: obj: \t", obj, type(obj)
        children_values = []
        for child in self.children:
            children_values.append(child.value)
        obj_value = obj.value
        if obj_value not in children_values:
            self.children.append(obj)
            if type(obj) == node:
                ###print "append_child: obj is an instance of node"
                obj.parent = self
            ###else:
                ###print "append_child: obj", obj, "is NOT an instance of node"
    
    def get_all_leaf(self):
        leaf_list = []
        ###print "get_all_leaf: self.children:", self.children, len(self.children)
        if len(self.children) > 0:
            for child_node in self.children:                
                leaf_list.extend(child_node.get_all_leaf())
            ###print "get_all_leaf: returning leaf_list: before merge \t", leaf_list
            leaf_list = uniquely_merge_multi_dimentional_list_of_lists(leaf_list)
            ###print "get_all_leaf: returning leaf_list: after merge \t", leaf_list
            ###print "@get_all_leaf: returning leaf_list: \t", leaf_list, type(leaf_list)
            return leaf_list
        ###print "@get_all_leaf: no children so returning self: \t", self, type(self)
        return [self]
    
    def get_path_from_all_leaf(self):
        print "*get_path_from_all_leaf: self", self
        path_list = []
        leaf_list = self.get_all_leaf()
        print "**get_path_from_all_leaf: leaf_list \n", leaf_list, len(leaf_list)
        
        if len(leaf_list) == 1 and self in leaf_list:
            path_list.append([self.value])
            return path_list
    
        elif len(leaf_list) > 0:
            for leaf in leaf_list:
                path = []
                print "***get_path_from_all_leaf: a leaf in leaf_list:", leaf, type(leaf)
                path.append(leaf.value)
                pointer_node = leaf
                while pointer_node.parent != self:
                    path.append(pointer_node.parent.value)
                    pointer_node = pointer_node.parent
                path.append(self.value)
                path_list.append(path)
            return path_list
        else:
            return []

# %%
def remove_duplicates_within_list(seq):
    seen = set()
    seen_add = seen.add
    return [ x for x in seq if not (x in seen or seen_add(x))]

# %%
def list_is_type(lst, typ):
    """
    Check if all elements in a list is the same specified type.
    """
    
    if type(lst) != list:
        raise TypeError("list_is_type(lst, typ): lst is not a list")
    elif len(lst) <= 0:
        raise ValueError("list_is_type(lst, typ): lst is empty")
    return all(isinstance(x,typ) for x in lst)

# %%
def remove_duplicated_lists_within_a_list_of_lists(list_of_lists):
    """
    Removes any duplicated lists, which contain same elements in same order, within a list of lists.
    """
    
    if type(list_of_lists) == list and len(list_of_lists) > 0 and list_is_type(list_of_lists, list) == True:
        list_of_lists.sort()
        trimmed = list(list_of_lists for list_of_lists,_ in itertools.groupby(list_of_lists))
        return trimmed
    else:
        raise TypeError("remove_duplicated_lists_within_a_list_of_lists(list_of_lists): list_of_lists should be in the form: [[],[],... ]")

# %%
def uniquely_merge_list_of_lists(list_of_lists):
    """
    Merge unique elements from lists within a list.
    
    Argument:
        list_of_lists - a list that contains multiple lists.
    
    Return:
        a new list that contains unique elements from all lists within a list of lists.
    """   
    
    if type(list_of_lists) == list and len(list_of_lists) > 0:
        
        if list_is_type(list_of_lists, list) == True:
            remove_duplicated_lists_within_a_list_of_lists(list_of_lists)
            merged_list = list(list_of_lists[0])
            for a_list in list_of_lists[1::]:
                    for e in a_list:
                        if e not in merged_list:
                            merged_list.append(e)
            return merged_list
        else:
            return list(list_of_lists)
    else:
        return list_of_lists
        raise TypeError("uniquely_merge_list_of_lists(list_of_lists): list_of_list must be a non-empty list")

# %%
def uniquely_merge_multi_dimentional_list_of_lists(multi_dimentional_list_of_lists):
    final_merged_list = uniquely_merge_list_of_lists(multi_dimentional_list_of_lists)
    if type(final_merged_list) == list and len(final_merged_list) > 0 and list_is_type(final_merged_list, list) == True:
        return uniquely_merge_multi_dimentional_list_of_lists(final_merged_list)
    else:
        return final_merged_list

# %%
def elements_match(list_of_lists, lst):
    return set(lst).issubset(uniquely_merge_multi_dimentional_list_of_lists(list_of_lists))

# %%
def get_matching_list(list_of_lists, lst):
    """
    Get any list that match a specified list.
    """
    
    if type(lst) != list:
        raise TypeError("get_matching_list(list_of_lists, lst): lst is not a list object")    
    elif type(list_of_lists) == list and len(list_of_lists) > 0 and list_is_type(list_of_lists, list) == True:
        matching_list = []
        for a_list in list_of_lists:
            if all([x in lst for x in a_list]) == True:
                matching_list.append(a_list)
        return matching_list
    else:
        raise TypeError("get_matching_list(list_of_lists, lst): list_of_lists should be in the form: [[],[],... ]")

# %%
def match_any_list(list_of_lists, lst):
    """
    Check if a list matches any of lists within a list.
    """
            
    if get_matching_list(list_of_lists, lst) == []:
        return False
    else:
        return True

# %%
def search_sbider_path_memory(input_dictionary, activated_paths, from_operon):
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print "~IN search_sbider_path_memory~"
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print
    print
    
    print "search_sbider_path_memory: activated_paths:", activated_paths
    print
    
    activated_ope_dic = {}
    activated_spe_dic = {}
    
    for path_idx, ope_spe_path in enumerate(activated_paths):
        activated_ope_dic[path_idx] = ope_spe_path[0] # ope
        activated_spe_dic[path_idx] = ope_spe_path[1] # spe
    
    
    print "search_sbider_path_memory: from_operon:", from_operon, type(from_operon)
    final_operon_requirement = input_dictionary[from_operon]
    
    activating_ope_list = []
    
    for path_idx, spe_produced in activated_spe_dic.items():
        for a_spe_produced in spe_produced:
            for and_spe_required in final_operon_requirement:
                if a_spe_produced in and_spe_required:
                    activating_ope_list.extend(activated_ope_dic.get(path_idx))
    
    print "search_sbider_path_memory: activating_ope_list:", activating_ope_list
    return activating_ope_list

# %%
def build_sbider_path_memory_tree(input_dictionary, activated_paths, start_operon):
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print "~IN build_sbider_path_memory_tree~"
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print
    print
    
    print "build_sbider_path_memory_tree: activated_paths:", activated_paths
    print
    
    root_ope = node(start_operon)

    temp_queue_ope = []
    temp_queue_ope.append(root_ope)
    
    temp_memory = []
        
    while len(activated_paths) > 0 and len(temp_queue_ope) > 0:
        print "\t build_sbider_path_memory_tree: activated_paths in while loop:", activated_paths
        print "\t build_sbider_path_memory_tree: temp_queue_ope:", temp_queue_ope
        
        from_node = temp_queue_ope.pop(0)
        from_operon = from_node.value

        print "\t build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory"
        children_operon = search_sbider_path_memory(input_dictionary, activated_paths, from_operon)
        print "\t build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory"
        print
        
        if len(children_operon) > 0:
            for child_operon in children_operon:
                if child_operon not in temp_memory:
                    child_node = node(child_operon)
                    from_node.append_child(child_node)
                    temp_queue_ope.append(child_node)
                    temp_memory.append(child_operon)
                    print "\t\t build_sbider_path_memory_tree: root_ope UPDATED \n", root_ope
                    print "*" * 99

            print "build_sbider_path_memory_tree: path from all ope leaf \n", root_ope.get_path_from_all_leaf()
            print
    
    return root_ope.get_path_from_all_leaf()

# %%
def build_indirect_sbider_path(input_dictionary,
                               output_dictionary,
                               input_species_list,
                               output_species_list,
                               path_queue,
                               final_operon_path_list,
                               
                               memory_operon,
                               memory_species,
                               
                               activated_paths):
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print "~IN build_indirect_sbider_path~"
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print
    print
    
    print "build_indirect_sbider_path: path_queue:", path_queue, len(path_queue)
    print "build_indirect_sbider_path: memory_operon:", memory_operon 
    print "build_indirect_sbider_path: memory_species:", memory_species
    print "build_indirect_sbider_path: activated_paths:", activated_paths
    print
    print "\t build_indirect_sbider_path: operons yet to be visited:", set(input_dictionary.keys()) - set(memory_operon)
    temp_memory_species = []
    for an_operon in set(input_dictionary.keys()) - set(memory_operon):
        print "\t\t build_indirect_sbider_path: OPERON:", an_operon
        activation_requirement = input_dictionary[an_operon]
        print "\t\t build_indirect_sbider_path: Avtivation Requirement:", activation_requirement
        if match_any_list(activation_requirement, memory_species) == True:
            print "\t\t\t build_indirect_sbider_path: Avtivation!!! of", an_operon
            just_produced_species = output_dictionary[an_operon]
            just_produced_unique_species = uniquely_merge_multi_dimentional_list_of_lists(just_produced_species)            
            
            if match_any_list(just_produced_species, output_species_list):
                print "\t\t\t build_indirect_sbider_path: Match!!!!!!!!!"
                matched_input_requirement = get_matching_list(activation_requirement, memory_species)
                matched_unique_input_requirement = uniquely_merge_multi_dimentional_list_of_lists(matched_input_requirement)
                if len(activated_paths) > 1:
                    print "\t\t\t build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree"
                    ope_path_backward = build_sbider_path_memory_tree(input_dictionary,
                                                                                     activated_paths,
                                                                                     an_operon,
                                                                                     )
                    print "\t\t\t build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree"
                    print
                
                    print "\t\t\t\t build_direct_sbider_path: BEFORE ope:", final_operon_path_list
                    final_operon_path_list.extend(ope_path_backward)
                    print "\t\t\t\t build_direct_sbider_path: AFTER ope:", final_operon_path_list
            else:
                if an_operon not in memory_operon:

                    path_queue.append(([an_operon],just_produced_unique_species))
                    
                    memory_operon.append(an_operon)
                    memory_operon = remove_duplicates_within_list(memory_operon)
                    
                    temp_memory_species.extend(just_produced_unique_species)
                    
                    activated_paths.append([[an_operon],just_produced_unique_species])
            print  
    memory_species.extend(temp_memory_species)
    memory_species = remove_duplicates_within_list(memory_species)
    print

    # if there is activated operon, run sbider_path again.
    if len(path_queue) > 0:
        print "build_indirect_sbider_path: ReENTERING--- build_direct_sbider_path"
        build_direct_sbider_path(input_dictionary,
                                 output_dictionary,
                                 input_species_list,
                                 output_species_list,
                                 path_queue,
                                 final_operon_path_list,
                                 memory_operon,
                                 memory_species,
                                 activated_paths)

# %%
def build_direct_sbider_path(input_dictionary,
                             output_dictionary,
                             input_species_list,
                             output_species_list,
                             path_queue,
                             final_operon_path_list,
                             memory_operon,
                             memory_species,
                             activated_paths,
                             indirect_flag):
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print "~IN build_direct_sbider_path~"
    print "~~~~~~~~~~~~~~~~~~~~~~~~~~~~~"
    print
    print
    
    print "build_direct_sbider_path: path_queue:", path_queue, len(path_queue)
    print "build_direct_sbider_path: memory_operon:", memory_operon 
    print "build_direct_sbider_path: memory_species:", memory_species
    print "build_direct_sbider_path: activated_paths:", activated_paths
    print
    
    while len(path_queue) != 0:
        print "\t build_direct_sbider_path: path_queue in while-loop:", path_queue, len(path_queue)
        
        (previously_visited_operon_list, just_previously_produced_species_list) = path_queue.pop(0)
        
        print "\t build_direct_sbider_path: operons to be visited:", set(input_dictionary.keys()) - set(uniquely_merge_multi_dimentional_list_of_lists(previously_visited_operon_list))
        for an_operon in set(input_dictionary.keys()) - set(uniquely_merge_multi_dimentional_list_of_lists(previously_visited_operon_list)):
            print "\t\t build_direct_sbider_path: OPERON:", an_operon
            
            if an_operon not in memory_operon:
                activation_requirement = input_dictionary[an_operon]
                print "\t\t build_direct_sbider_path: Avtivation Requirement:", activation_requirement

                if match_any_list(activation_requirement, just_previously_produced_species_list) == True:
                    print "\t\t\t build_direct_sbider_path: Activation!!! of", an_operon

                    visited_operon_list = previously_visited_operon_list + [an_operon]

                    just_produced_species = output_dictionary[an_operon]
                    just_produced_unique_species = uniquely_merge_multi_dimentional_list_of_lists(just_produced_species)

                    if match_any_list(just_produced_species, output_species_list):
                        print "\t\t\t\t build_direct_sbider_path: Match!!!!!!!!!"
                        
                        if indirect_flag == False:
                            print "\t\t\t\t build_direct_sbider_path: BEFORE ope:", final_operon_path_list
                            final_operon_path_list.append(visited_operon_list)
                            print "\t\t\t\t build_direct_sbider_path: AFTER ope:", final_operon_path_list
                    else:
                        path_queue.append((visited_operon_list,just_produced_unique_species))
                        memory_operon.append(an_operon)
                        memory_operon = remove_duplicates_within_list(memory_operon)                        
                        memory_species.extend(just_produced_unique_species)
                        memory_species = remove_duplicates_within_list(memory_species)

                    activated_paths.append([[an_operon],just_produced_unique_species])                        
                   
        print "\t build_direct_sbider_path: exiting while loop for queue"
        print
    
    if indirect_flag == True:
        print "build_direct_sbider_path: ENTERING--- build_indirect_sbider_path"
        final_operon_path_list = build_indirect_sbider_path(input_dictionary,
                                   output_dictionary,
                                   input_species_list,
                                   output_species_list,
                                   path_queue,
                                   final_operon_path_list,
                                   memory_operon,
                                   memory_species,
                                   activated_paths)
        print "build_direct_sbider_path: ---RETURNING build_indirect_sbider_path"
        print
        
    return final_operon_path_list

# %%
def get_sbider_path(inp_dic,
                    outp_dic,
                    inp_spe,
                    outp_spe,
                    indirect_flag=False):
    print "~~~~~~~~~~~~~~~~~~~~"
    print "~IN get_sbider_path~"
    print "~~~~~~~~~~~~~~~~~~~~"
    print
    print
    
    final_ope_path = []
    
    path_queue = [([],inp_spe)]
    
    memory_ope = []
    memory_spe = []
    memory_spe.extend(inp_spe)
    
    activated_paths = []
    
    print "get_sbider_path: ENTERING--- build_direct_sbider_path"
    build_direct_sbider_path(inp_dic,
                             outp_dic,
                             inp_spe,
                             outp_spe,
                             path_queue,
                             final_ope_path,
                             memory_ope,
                             memory_spe,
                             activated_paths,
                             indirect_flag)
    print "get_sbider_path: ---RETURNING build_direct_sbider_path"
    print
    
    print "get_sbider_path: final_ope_path: BEFORE", final_ope_path
    if len(final_ope_path) > 0:
        final_ope_path = remove_duplicated_lists_within_a_list_of_lists(final_ope_path)
    print "get_sbider_path: final_ope_path: AFTER", final_ope_path
    
    return final_ope_path

# %%
input_path_dictionary = {'19,2': [['20', '21']], '81,1': [['20', '21']], '81,3': [['1']], '19,1': [['22']], '51,1': [['20', '21'], ['13', '2']], '57,1': [['20', '21'], ['13', '2']], '90,1': [['19', '9']], '1,1': [['33', '9'], ['20', '21']], '68,1': [['36', '8']], '36,1': [['47']], '79,1': [['13', '2']], '79,2': [['22']], '79,3': [['1']], '94,1': [['4', '5']], '5,2': [['1']], '5,1': [['13', '2'], ['36', '8']], '3,1': [['36', '8']], '3,2': [['1']], '77,2': [['13', '2']], '77,1': [['20', '21']], '46,2': [['20', '21']], '46,3': [['1']], '46,1': [['19', '9']], '72,3': [['20', '21']], '40,1': [['6', '7']], '72,1': [['1']], '91,2': [['1']], '91,1': [['36', '8']], '21,2': [['22']], '30,1': [['31', '32']], '21,1': [['20', '21']], '25,2': [['19', '9']], '25,1': [['1']], '37,2': [['1']], '104,1': [['19', '9']], '37,1': [['13', '2']], '31,1': [['31', '32']], '31,2': [['22']], '39,1': [['6', '7']], '39,2': [['47']], '95,2': [['1']], '95,1': [['36', '8']], '6,1': [['13', '2'], ['3', '45']], '80,1': [['20', '21']], '80,2': [['22']], '6,2': [['1']], '74,1': [['13', '2']], '74,2': [['1']], '16,1': [['36', '8']], '8,2': [['1']], '8,1': [['36', '8'], ['13', '2']], '92,1': [['36', '8']], '92,2': [['1']], '71,1': [['1']], '71,2': [['36', '8']], '75,1': [['13', '2']], '98,2': [['1']], '98,1': [['36', '8']], '75,2': [['1']], '43,1': [['22']], '101,1': [['23', '28']], '101,3': [['19', '9']], '15,1': [['20', '21']], '101,5': [['1']], '101,4': [['1']], '24,2': [['13', '2']], '24,1': [['1']], '18,2': [['22']], '18,1': [['20', '21']], '49,1': [['20', '21']], '58,1': [['19', '9']], '49,2': [['1']], '55,2': [['37', '41'], ['19', '9']], '102,2': [['13', '2']], '55,1': [['37', '48']], '96,1': [['13', '2']], '96,2': [['1']], '53,1': [['37', '48']], '13,1': [['22']], '102,1': [['29', '30']], '65,1': [['15']], '2,1': [['13', '2']], '2,2': [['1']], '4,2': [['1']], '4,1': [['3', '45']], '101,2': [['36', '8']], '102,5': [['1']], '20,2': [['20', '21']], '20,1': [['36', '8']], '47,3': [['1']], '47,2': [['19', '21']], '47,1': [['19', '9']], '17,1': [['22']], '73,4': [['1']], '73,2': [['20', '21']], '73,3': [['36', '8']], '73,1': [['22']], '44,1': [['19', '9']], '44,2': [['22']], '29,3': [['1']], '29,2': [['22']], '29,1': [['20', '27']], '93,1': [['13', '2']], '93,2': [['1']], '89,1': [['20', '21']], '89,2': [['1']], '59,1': [['19']], '34,1': [['36']], '48,1': [['20', '21']], '48,2': [['1']], '23,1': [['20', '27']], '23,2': [['1']], '33,2': [['1']], '102,3': [['20', '21']], '33,1': [['44']], '78,1': [['34'], ['16', '38']], '102,4': [['1']], '78,2': [['1']], '67,1': [['36', '8']], '35,1': [['13', '2']], '35,2': [['1']], '82,2': [['1']], '12,1': [['22']], '82,1': [['20', '21']], '50,1': [['20', '21'], ['13', '2']], '97,1': [['29', '30']], '54,3': [['37'], ['19', '9']], '80,3': [['1']], '9,2': [['1']], '9,1': [['13', '2'], ['3', '45']], '7,1': [['36', '8'], ['3', '45']], '7,2': [['1']], '56,3': [['36', '8']], '90,2': [['1']], '76,2': [['1']], '99,2': [['1']], '10,2': [['1']], '10,1': [['36', '8'], ['3', '45']], '99,1': [['19', '9']], '76,1': [['13', '2']], '69,2': [['10', '9']], '69,1': [['1']], '28,2': [['19', '9']], '28,1': [['1']], '72,2': [['36', '8']], '103,1': [['20', '21']], '81,2': [['22']], '88,1': [['13', '2']], '88,2': [['1']], '100,1': [['23', '28']], '56,1': [['19', '37'], ['22']], '54,2': [['36', '8']], '54,1': [['37', '48']], '56,2': [['37', '48']], '22,1': [['36', '8']], '22,2': [['20', '21']], '14,1': [['22']]}
output_path_dictionary = {'19,2': [['22']], '81,1': [['22']], '81,3': [['21']], '19,1': [['11']], '51,1': [['21']], '57,1': [['19', '9']], '90,1': [['42']], '1,1': [['11']], '68,1': [['19']], '36,1': [['11']], '79,1': [['22']], '79,2': [['11']], '79,3': [['2']], '94,1': [['42']], '5,2': [['2', '36']], '5,1': [['39']], '3,1': [['39']], '3,2': [['36']], '77,2': [['38']], '77,1': [['16']], '46,2': [['11']], '46,3': [['9']], '46,1': [['21']], '72,3': [['39']], '40,1': [['11']], '72,1': [['11', '36']], '91,2': [['36']], '91,1': [['42']], '21,2': [['21']], '30,1': [['11']], '21,1': [['11', '22']], '25,2': [['11']], '25,1': [['9']], '37,2': [['2']], '104,1': [['14']], '37,1': [['7']], '31,1': [['22']], '31,2': [['11']], '39,1': [['25']], '39,2': [['7']], '95,2': [['36']], '95,1': [['30']], '6,1': [['39']], '80,1': [['22']], '80,2': [['11']], '6,2': [['2', '3']], '74,1': [['34']], '74,2': [['2']], '16,1': [['11']], '8,2': [['2', '36']], '8,1': [['22']], '92,1': [['18']], '92,2': [['36']], '71,1': [['36']], '71,2': [['39']], '75,1': [['16']], '98,2': [['36']], '98,1': [['28']], '75,2': [['2']], '43,1': [['17']], '101,1': [['18']], '101,3': [['23']], '15,1': [['11']], '101,5': [['36']], '101,4': [['9']], '24,2': [['11']], '24,1': [['2']], '18,2': [['21']], '18,1': [['11']], '49,1': [['42']], '58,1': [['14']], '49,2': [['21']], '55,2': [['43']], '102,2': [['29']], '55,1': [['22']], '96,1': [['29']], '96,2': [['2']], '53,1': [['43']], '13,1': [['40']], '102,1': [['5']], '65,1': [['11']], '2,1': [['39']], '2,2': [['2']], '4,2': [['3']], '4,1': [['39']], '101,2': [['28']], '102,5': [['21']], '20,2': [['36']], '20,1': [['11']], '47,3': [['9']], '47,2': [['42']], '47,1': [['21']], '17,1': [['11']], '73,4': [['36']], '73,2': [['22']], '73,3': [['21']], '73,1': [['39']], '44,1': [['22']], '44,2': [['21']], '29,3': [['27']], '29,2': [['11']], '29,1': [['22']], '93,1': [['5']], '93,2': [['2']], '89,1': [['42']], '89,2': [['21']], '59,1': [['24']], '34,1': [['11']], '48,1': [['26']], '48,2': [['21']], '23,1': [['11']], '23,2': [['27']], '33,2': [['12']], '102,3': [['30']], '33,1': [['6']], '78,1': [['11']], '102,4': [['2']], '78,2': [['21']], '67,1': [['11']], '35,1': [['11']], '35,2': [['2']], '82,2': [['21']], '12,1': [['39']], '82,1': [['39']], '50,1': [['11']], '97,1': [['42']], '54,3': [['43']], '80,3': [['21']], '9,2': [['2', '3']], '9,1': [['22']], '7,1': [['39']], '7,2': [['3', '36']], '56,3': [['9']], '90,2': [['9']], '76,2': [['2']], '99,2': [['9']], '10,2': [['3', '36']], '10,1': [['22']], '99,1': [['23']], '76,1': [['38']], '69,2': [['22', '26']], '69,1': [['9']], '28,2': [['31']], '28,1': [['9']], '72,2': [['21']], '103,1': [['46', '9']], '81,2': [['11']], '88,1': [['42']], '88,2': [['2']], '100,1': [['42']], '56,1': [['43']], '54,2': [['1']], '54,1': [['19']], '56,2': [['19', '22']], '22,1': [['21']], '22,2': [['11', '36']], '14,1': [['35']]}
inp = ['29', '30']
outp = ['5']

'''
input_path_dictionary = {'Op1' : [['10']],
                         'Op2' : [['10']],
                         'Op3' : [['2.1', '11']],
                         'Op4' : [['2.2', '12']],
                         'Op5' : [['3.1', '3.2']],
                         'Op6' : [['99']],
                         'Op7' : [['999']],
                         'Op8' : [['a']],
                         'Op9' : [['b']],
                         'Op10' : [['c']]

                         }
output_path_dictionary = {'Op1' : [['2.1']],
                          'Op2' : [['2.2']],
                          'Op3' : [['3.1']],
                          'Op4' : [['3.2', '10']],
                          'Op5' : [['99']],
                          'Op6' : [['999']],
                          'Op7' : [['9999']],
                          'Op8' : [['b']],
                          'Op9' : [['c']],
                          'Op10' : [['99']]
                          }
inp = ['a']
outp = ['c']
'''
# Out:
# "\ninput_path_dictionary = {'Op1' : [['10']],\n                         'Op2' : [['10']],\n                         'Op3' : [['2.1', '11']],\n                         'Op4' : [['2.2', '12']],\n                         'Op5' : [['3.1', '3.2']],\n                         'Op6' : [['99']],\n                         'Op7' : [['999']],\n                         'Op8' : [['a']],\n                         'Op9' : [['b']],\n                         'Op10' : [['c']]\n\n                         }\noutput_path_dictionary = {'Op1' : [['2.1']],\n                          'Op2' : [['2.2']],\n                          'Op3' : [['3.1']],\n                          'Op4' : [['3.2', '10']],\n                          'Op5' : [['99']],\n                          'Op6' : [['999']],\n                          'Op7' : [['9999']],\n                          'Op8' : [['b']],\n                          'Op9' : [['c']],\n                          'Op10' : [['99']]\n                          }\ninp = ['']\noutp = ['999']"

# %%
a = get_sbider_path(input_path_dictionary, output_path_dictionary, inp, outp, True)
# Out:
# ~~~~~~~~~~~~~~~~~~~~
# ~IN get_sbider_path~
# ~~~~~~~~~~~~~~~~~~~~
#
#
# get_sbider_path: ENTERING--- build_direct_sbider_path
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~IN build_direct_sbider_path~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# build_direct_sbider_path: path_queue: [([], ['29', '30'])] 1
# build_direct_sbider_path: memory_operon: []
# build_direct_sbider_path: memory_species: ['29', '30']
# build_direct_sbider_path: activated_paths: []
#
# 	 build_direct_sbider_path: path_queue in while-loop: [([], ['29', '30'])] 1
# 	 build_direct_sbider_path: operons to be visited: set(['19,2', '81,1', '81,3', '19,1', '51,1', '57,1', '90,1', '1,1', '68,1', '36,1', '79,1', '79,2', '79,3', '94,1', '5,2', '5,1', '3,1', '3,2', '77,2', '77,1', '46,2', '46,3', '46,1', '72,3', '40,1', '72,1', '91,2', '91,1', '8,2', '30,1', '8,1', '25,2', '25,1', '37,2', '104,1', '37,1', '31,1', '31,2', '39,1', '39,2', '95,2', '95,1', '12,1', '80,1', '80,2', '6,2', '74,1', '74,2', '16,1', '21,2', '21,1', '92,1', '92,2', '71,1', '71,2', '75,1', '98,2', '98,1', '75,2', '43,1', '101,1', '101,3', '101,2', '101,5', '101,4', '24,2', '24,1', '18,2', '18,1', '49,1', '58,1', '49,2', '55,2', '102,2', '55,1', '96,1', '96,2', '53,1', '13,1', '102,1', '2,1', '2,2', '4,2', '4,1', '102,5', '20,2', '20,1', '47,3', '47,2', '47,1', '17,1', '15,1', '73,4', '73,2', '73,3', '73,1', '44,1', '44,2', '29,3', '29,2', '29,1', '93,1', '93,2', '89,1', '89,2', '59,1', '34,1', '48,1', '48,2', '23,1', '23,2', '33,2', '102,3', '33,1', '78,1', '102,4', '78,2', '67,1', '35,1', '65,1', '82,2', '6,1', '82,1', '50,1', '97,1', '56,1', '80,3', '9,2', '9,1', '7,1', '7,2', '56,3', '90,2', '76,2', '99,2', '10,2', '10,1', '99,1', '76,1', '69,2', '69,1', '28,2', '35,2', '28,1', '72,2', '103,1', '81,2', '88,1', '88,2', '100,1', '54,3', '54,2', '54,1', '56,2', '22,1', '22,2', '14,1'])
# 		 build_direct_sbider_path: OPERON: 19,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 19,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 51,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 57,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 90,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 1,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['33', '9'], ['20', '21']]
# 		 build_direct_sbider_path: OPERON: 68,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 36,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['47']]
# 		 build_direct_sbider_path: OPERON: 79,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 79,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 79,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 94,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['4', '5']]
# 		 build_direct_sbider_path: OPERON: 5,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 5,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['36', '8']]
# 		 build_direct_sbider_path: OPERON: 3,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 3,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 77,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 77,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 46,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 46,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 46,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 72,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 40,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_direct_sbider_path: OPERON: 72,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 91,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 91,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 8,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 30,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_direct_sbider_path: OPERON: 8,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 25,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 25,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 37,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 104,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 37,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 31,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_direct_sbider_path: OPERON: 31,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 39,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_direct_sbider_path: OPERON: 39,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['47']]
# 		 build_direct_sbider_path: OPERON: 95,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 95,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 12,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 80,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 80,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 6,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 74,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 74,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 16,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 21,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 21,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 92,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 92,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 71,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 71,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 75,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 98,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 98,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 75,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 43,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 101,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_direct_sbider_path: OPERON: 101,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 101,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 101,5
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 101,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 24,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 24,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 18,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 18,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 49,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 58,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 49,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 55,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '41'], ['19', '9']]
# 		 build_direct_sbider_path: OPERON: 102,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 55,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 96,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 96,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 53,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 13,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 102,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['29', '30']]
# 			 build_direct_sbider_path: Activation!!! of 102,1
# 				 build_direct_sbider_path: Match!!!!!!!!!
# 		 build_direct_sbider_path: OPERON: 2,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 2,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 4,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 4,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['3', '45']]
# 		 build_direct_sbider_path: OPERON: 102,5
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 20,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 20,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 47,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 47,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '21']]
# 		 build_direct_sbider_path: OPERON: 47,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 17,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 15,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 73,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 73,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 73,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 73,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 44,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 44,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 29,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 29,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 29,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_direct_sbider_path: OPERON: 93,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 93,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 89,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 89,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 59,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19']]
# 		 build_direct_sbider_path: OPERON: 34,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36']]
# 		 build_direct_sbider_path: OPERON: 48,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 48,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 23,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_direct_sbider_path: OPERON: 23,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 33,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 102,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 33,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['44']]
# 		 build_direct_sbider_path: OPERON: 78,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['34'], ['16', '38']]
# 		 build_direct_sbider_path: OPERON: 102,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 78,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 67,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 35,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 65,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['15']]
# 		 build_direct_sbider_path: OPERON: 82,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 6,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 82,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 50,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 97,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['29', '30']]
# 			 build_direct_sbider_path: Activation!!! of 97,1
# 		 build_direct_sbider_path: OPERON: 56,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '37'], ['22']]
# 		 build_direct_sbider_path: OPERON: 80,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 9,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 9,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 7,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 7,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 56,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 90,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 76,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 99,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 10,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 10,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 99,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 76,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 69,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['10', '9']]
# 		 build_direct_sbider_path: OPERON: 69,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 28,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 35,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 28,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 72,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 103,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 88,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 88,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 100,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_direct_sbider_path: OPERON: 54,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['37'], ['19', '9']]
# 		 build_direct_sbider_path: OPERON: 54,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 54,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 56,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 22,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 22,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 14,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 	 build_direct_sbider_path: exiting while loop for queue
#
# 	 build_direct_sbider_path: path_queue in while-loop: [(['97,1'], ['42'])] 1
# 	 build_direct_sbider_path: operons to be visited: set(['19,2', '81,1', '81,3', '19,1', '51,1', '57,1', '90,1', '1,1', '68,1', '36,1', '79,1', '79,2', '79,3', '94,1', '5,2', '5,1', '3,1', '3,2', '77,2', '77,1', '46,2', '46,3', '46,1', '72,3', '40,1', '72,1', '91,2', '91,1', '8,2', '30,1', '8,1', '25,2', '25,1', '37,2', '104,1', '37,1', '31,1', '31,2', '39,1', '39,2', '95,2', '95,1', '12,1', '80,1', '80,2', '6,2', '74,1', '74,2', '16,1', '21,2', '21,1', '92,1', '92,2', '71,1', '71,2', '75,1', '98,2', '98,1', '75,2', '43,1', '101,1', '101,3', '101,2', '101,5', '101,4', '24,2', '24,1', '18,2', '18,1', '49,1', '58,1', '49,2', '55,2', '102,2', '55,1', '96,1', '96,2', '53,1', '13,1', '102,1', '2,1', '2,2', '4,2', '4,1', '102,5', '20,2', '20,1', '47,3', '47,2', '47,1', '17,1', '15,1', '73,4', '73,2', '73,3', '73,1', '44,1', '44,2', '29,3', '29,2', '29,1', '93,1', '93,2', '89,1', '89,2', '59,1', '34,1', '48,1', '48,2', '23,1', '23,2', '33,2', '102,3', '33,1', '78,1', '102,4', '78,2', '67,1', '35,1', '65,1', '82,2', '6,1', '82,1', '50,1', '56,1', '80,3', '9,2', '9,1', '7,1', '7,2', '56,3', '90,2', '76,2', '99,2', '10,2', '10,1', '99,1', '76,1', '69,2', '69,1', '28,2', '35,2', '28,1', '72,2', '103,1', '81,2', '88,1', '88,2', '100,1', '54,3', '54,2', '54,1', '56,2', '22,1', '22,2', '14,1'])
# 		 build_direct_sbider_path: OPERON: 19,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 19,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 51,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 57,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 90,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 1,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['33', '9'], ['20', '21']]
# 		 build_direct_sbider_path: OPERON: 68,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 36,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['47']]
# 		 build_direct_sbider_path: OPERON: 79,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 79,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 79,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 94,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['4', '5']]
# 		 build_direct_sbider_path: OPERON: 5,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 5,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['36', '8']]
# 		 build_direct_sbider_path: OPERON: 3,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 3,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 77,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 77,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 46,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 46,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 46,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 72,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 40,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_direct_sbider_path: OPERON: 72,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 91,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 91,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 8,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 30,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_direct_sbider_path: OPERON: 8,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 25,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 25,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 37,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 104,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 37,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 31,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_direct_sbider_path: OPERON: 31,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 39,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_direct_sbider_path: OPERON: 39,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['47']]
# 		 build_direct_sbider_path: OPERON: 95,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 95,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 12,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 80,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 80,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 6,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 74,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 74,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 16,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 21,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 21,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 92,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 92,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 71,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 71,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 75,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 98,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 98,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 75,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 43,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 101,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_direct_sbider_path: OPERON: 101,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 101,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 101,5
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 101,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 24,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 24,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 18,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 18,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 49,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 58,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 49,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 55,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '41'], ['19', '9']]
# 		 build_direct_sbider_path: OPERON: 102,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 55,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 96,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 96,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 53,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 13,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 102,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['29', '30']]
# 		 build_direct_sbider_path: OPERON: 2,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 2,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 4,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 4,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['3', '45']]
# 		 build_direct_sbider_path: OPERON: 102,5
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 20,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 20,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 47,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 47,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '21']]
# 		 build_direct_sbider_path: OPERON: 47,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 17,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 15,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 73,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 73,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 73,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 73,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 44,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 44,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 29,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 29,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 29,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_direct_sbider_path: OPERON: 93,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 93,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 89,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 89,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 59,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19']]
# 		 build_direct_sbider_path: OPERON: 34,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36']]
# 		 build_direct_sbider_path: OPERON: 48,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 48,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 23,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_direct_sbider_path: OPERON: 23,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 33,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 102,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 33,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['44']]
# 		 build_direct_sbider_path: OPERON: 78,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['34'], ['16', '38']]
# 		 build_direct_sbider_path: OPERON: 102,4
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 78,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 67,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 35,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 65,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['15']]
# 		 build_direct_sbider_path: OPERON: 82,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 6,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 82,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 50,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_direct_sbider_path: OPERON: 56,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '37'], ['22']]
# 		 build_direct_sbider_path: OPERON: 80,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 9,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 9,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 7,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 7,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 56,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 90,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 76,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 99,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 10,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 10,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_direct_sbider_path: OPERON: 99,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 76,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 69,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['10', '9']]
# 		 build_direct_sbider_path: OPERON: 69,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 28,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_direct_sbider_path: OPERON: 35,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 28,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 72,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 103,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 81,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 		 build_direct_sbider_path: OPERON: 88,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_direct_sbider_path: OPERON: 88,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['1']]
# 		 build_direct_sbider_path: OPERON: 100,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_direct_sbider_path: OPERON: 54,3
# 		 build_direct_sbider_path: Avtivation Requirement: [['37'], ['19', '9']]
# 		 build_direct_sbider_path: OPERON: 54,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 54,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 56,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_direct_sbider_path: OPERON: 22,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_direct_sbider_path: OPERON: 22,2
# 		 build_direct_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_direct_sbider_path: OPERON: 14,1
# 		 build_direct_sbider_path: Avtivation Requirement: [['22']]
# 	 build_direct_sbider_path: exiting while loop for queue
#
# build_direct_sbider_path: ENTERING--- build_indirect_sbider_path
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~IN build_indirect_sbider_path~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# build_indirect_sbider_path: path_queue: [] 0
# build_indirect_sbider_path: memory_operon: ['97,1']
# build_indirect_sbider_path: memory_species: ['29', '30', '42']
# build_indirect_sbider_path: activated_paths: [[['102,1'], ['5']], [['97,1'], ['42']]]
#
# 	 build_indirect_sbider_path: operons yet to be visited: set(['19,2', '81,1', '81,3', '19,1', '51,1', '57,1', '90,1', '1,1', '68,1', '36,1', '79,1', '79,2', '79,3', '94,1', '5,2', '5,1', '3,1', '3,2', '77,2', '77,1', '46,2', '46,3', '46,1', '72,3', '40,1', '72,1', '91,2', '91,1', '8,2', '30,1', '8,1', '25,2', '25,1', '37,2', '104,1', '37,1', '31,1', '31,2', '39,1', '39,2', '95,2', '95,1', '12,1', '80,1', '80,2', '6,2', '74,1', '74,2', '16,1', '21,2', '21,1', '92,1', '92,2', '71,1', '71,2', '75,1', '98,2', '98,1', '75,2', '43,1', '101,1', '101,3', '101,2', '101,5', '101,4', '24,2', '24,1', '18,2', '18,1', '49,1', '58,1', '49,2', '55,2', '102,2', '55,1', '96,1', '96,2', '53,1', '13,1', '102,1', '2,1', '2,2', '4,2', '4,1', '102,5', '20,2', '20,1', '47,3', '47,2', '47,1', '17,1', '15,1', '73,4', '73,2', '73,3', '73,1', '44,1', '44,2', '29,3', '29,2', '29,1', '93,1', '93,2', '89,1', '89,2', '59,1', '34,1', '48,1', '48,2', '23,1', '23,2', '33,2', '102,3', '33,1', '78,1', '102,4', '78,2', '67,1', '35,1', '65,1', '82,2', '6,1', '82,1', '50,1', '56,1', '80,3', '9,2', '9,1', '7,1', '7,2', '56,3', '90,2', '76,2', '99,2', '10,2', '10,1', '99,1', '76,1', '69,2', '69,1', '28,2', '35,2', '28,1', '72,2', '103,1', '81,2', '88,1', '88,2', '100,1', '54,3', '54,2', '54,1', '56,2', '22,1', '22,2', '14,1'])
# 		 build_indirect_sbider_path: OPERON: 19,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 81,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 81,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 19,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 51,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 57,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 90,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 1,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['33', '9'], ['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 68,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 36,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['47']]
# 		 build_indirect_sbider_path: OPERON: 79,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 79,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 79,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 94,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['4', '5']]
# 		 build_indirect_sbider_path: OPERON: 5,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 5,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2'], ['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 3,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 3,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 77,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 77,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 46,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 46,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 46,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 72,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 40,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_indirect_sbider_path: OPERON: 72,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 91,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 91,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 8,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 30,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_indirect_sbider_path: OPERON: 8,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8'], ['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 25,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 25,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 37,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 104,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 37,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 31,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['31', '32']]
# 		 build_indirect_sbider_path: OPERON: 31,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 39,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['6', '7']]
# 		 build_indirect_sbider_path: OPERON: 39,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['47']]
# 		 build_indirect_sbider_path: OPERON: 95,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 95,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 12,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 80,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 80,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 6,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 74,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 74,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 16,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 21,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 21,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 92,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 92,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 71,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 71,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 75,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 98,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 98,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 75,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 43,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 101,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_indirect_sbider_path: OPERON: 101,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 101,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 101,5
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 101,4
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 24,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 24,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 18,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 18,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 49,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 58,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 49,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 55,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37', '41'], ['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 102,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 55,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_indirect_sbider_path: OPERON: 96,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 96,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 53,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_indirect_sbider_path: OPERON: 13,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 102,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['29', '30']]
# 			 build_indirect_sbider_path: Avtivation!!! of 102,1
# 			 build_indirect_sbider_path: Match!!!!!!!!!
# 			 build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~IN build_sbider_path_memory_tree~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# build_sbider_path_memory_tree: activated_paths: [[['102,1'], ['5']], [['97,1'], ['42']]]
#
# 	 build_sbider_path_memory_tree: activated_paths in while loop: [[['102,1'], ['5']], [['97,1'], ['42']]]
# 	 build_sbider_path_memory_tree: temp_queue_ope: ['102,1'
# ]
# 	 build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ~IN search_sbider_path_memory~
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# search_sbider_path_memory: activated_paths: [[['102,1'], ['5']], [['97,1'], ['42']]]
#
# search_sbider_path_memory: from_operon: 102,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# 	 build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
#
# *get_path_from_all_leaf: self '102,1'
#
# **get_path_from_all_leaf: leaf_list
# ['102,1'
# ] 1
# 			 build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree
#
# 				 build_direct_sbider_path: BEFORE ope: []
# 				 build_direct_sbider_path: AFTER ope: [['102,1']]
#
# 		 build_indirect_sbider_path: OPERON: 2,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 2,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 4,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 4,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['3', '45']]
# 		 build_indirect_sbider_path: OPERON: 102,5
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 20,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 20,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 47,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 47,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '21']]
# 		 build_indirect_sbider_path: OPERON: 47,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 17,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 15,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 73,4
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 73,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 73,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 73,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 44,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 44,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 29,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 29,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 29,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_indirect_sbider_path: OPERON: 93,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 93,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 89,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 89,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 59,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19']]
# 		 build_indirect_sbider_path: OPERON: 34,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36']]
# 		 build_indirect_sbider_path: OPERON: 48,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 48,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 23,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '27']]
# 		 build_indirect_sbider_path: OPERON: 23,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 33,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 102,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 33,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['44']]
# 		 build_indirect_sbider_path: OPERON: 78,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['34'], ['16', '38']]
# 		 build_indirect_sbider_path: OPERON: 102,4
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 78,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 67,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 35,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 65,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['15']]
# 		 build_indirect_sbider_path: OPERON: 82,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 6,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_indirect_sbider_path: OPERON: 82,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 50,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21'], ['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 56,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '37'], ['22']]
# 		 build_indirect_sbider_path: OPERON: 80,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 9,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 9,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2'], ['3', '45']]
# 		 build_indirect_sbider_path: OPERON: 7,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_indirect_sbider_path: OPERON: 7,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 56,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 90,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 76,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 99,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 10,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 10,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8'], ['3', '45']]
# 		 build_indirect_sbider_path: OPERON: 99,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 76,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 69,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['10', '9']]
# 		 build_indirect_sbider_path: OPERON: 69,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 28,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 35,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 28,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 72,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 103,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 81,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
# 		 build_indirect_sbider_path: OPERON: 88,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['13', '2']]
# 		 build_indirect_sbider_path: OPERON: 88,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['1']]
# 		 build_indirect_sbider_path: OPERON: 100,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['23', '28']]
# 		 build_indirect_sbider_path: OPERON: 54,3
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37'], ['19', '9']]
# 		 build_indirect_sbider_path: OPERON: 54,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 54,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_indirect_sbider_path: OPERON: 56,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['37', '48']]
# 		 build_indirect_sbider_path: OPERON: 22,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['36', '8']]
# 		 build_indirect_sbider_path: OPERON: 22,2
# 		 build_indirect_sbider_path: Avtivation Requirement: [['20', '21']]
# 		 build_indirect_sbider_path: OPERON: 14,1
# 		 build_indirect_sbider_path: Avtivation Requirement: [['22']]
#
# build_direct_sbider_path: ---RETURNING build_indirect_sbider_path
#
# get_sbider_path: ---RETURNING build_direct_sbider_path
#
# get_sbider_path: final_ope_path: BEFORE [['102,1']]
# get_sbider_path: final_ope_path: AFTER [['102,1']]
