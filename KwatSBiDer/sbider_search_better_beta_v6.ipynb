# %%
import matplotlib.pyplot as plt
import networkx as nx
import itertools
import collections
import weakref

# %%
class node(object):
    
    def __init__(self, value):
        self.value = value
        ###print "node.__init__(self, value): self, value:", value, type(value)
        self.children = []
        self.parent = None
    
    def __repr__(self, level=0):
        ret = "\t"*level+repr(self.value)+"\n"
        for child in self.children:
            ret += child.__repr__(level+1)
        return ret
    
    def append_child(self, obj):
        ###print "append_child: obj: \t", obj, type(obj)
        children_values = []
        for child in self.children:
            children_values.append(child.value)
        obj_value = obj.value
        if obj_value not in children_values:
            self.children.append(obj)
            if type(obj) == node:
                ###print "append_child: obj is an instance of node"
                obj.parent = self
            ###else:
                ###print "append_child: obj", obj, "is NOT an instance of node"
    
    def get_all_leaf(self):
        leaf_list = []
        if len(self.children) > 0:
            for child_node in self.children:                
                leaf_list.extend(child_node.get_all_leaf())
            ###print "get_all_leaf: returning leaf_list: before merge \t", leaf_list
            leaf_list = uniquely_merge_multi_dimentional_list_of_lists(leaf_list)
            ###print "get_all_leaf: returning leaf_list: after merge \t", leaf_list
            ###print "@get_all_leaf: returning leaf_list: \t", leaf_list, type(leaf_list)
            return leaf_list
        ###print "@get_all_leaf: no children so returning self: \t", self, type(self)
        return [self]
    
    def get_path_from_all_leaf(self):
        ###print "*get_path_from_all_leaf: self", self
        path_list = []
        leaf_list = self.get_all_leaf()
        if len(leaf_list) > 1:
            ###print "**get_path_from_all_leaf: leaf_list \n", leaf_list
            for leaf in leaf_list:
                path = []
                ###print "***get_path_from_all_leaf: leaf:", leaf, type(leaf)
                path.append(leaf.value)
                pointer_node = leaf
                while pointer_node.parent != self:
                    path.append(pointer_node.parent.value)
                    pointer_node = pointer_node.parent
                path.append(self.value)
                path_list.append(path)
        return path_list

# %%
def remove_duplicates_within_list(seq):
    seen = set()
    seen_add = seen.add
    return [ x for x in seq if not (x in seen or seen_add(x))]

# %%
def list_is_type(lst, typ):
    """
    Check if all elements in a list is the same specified type.
    """
    
    if type(lst) != list:
        raise TypeError("list_is_type(lst, typ): lst is not a list")
    elif len(lst) <= 0:
        raise ValueError("list_is_type(lst, typ): lst is empty")
    return all(isinstance(x,typ) for x in lst)

# %%
def remove_duplicated_lists_within_a_list_of_lists(list_of_lists):
    """
    Removes any duplicated lists, which contain same elements in same order, within a list of lists.
    """
    
    if type(list_of_lists) == list and len(list_of_lists) > 0 and list_is_type(list_of_lists, list) == True:
        list_of_lists.sort()
        trimmed = list(list_of_lists for list_of_lists,_ in itertools.groupby(list_of_lists))
        return trimmed
    else:
        raise TypeError("remove_duplicated_lists_within_a_list_of_lists(list_of_lists): list_of_lists should be in the form: [[],[],... ]")

# %%
def uniquely_merge_list_of_lists(list_of_lists):
    """
    Merge unique elements from lists within a list.
    
    Argument:
        list_of_lists - a list that contains multiple lists.
    
    Return:
        a new list that contains unique elements from all lists within a list of lists.
    """   
    
    if type(list_of_lists) == list and len(list_of_lists) > 0:
        
        if list_is_type(list_of_lists, list) == True:
            remove_duplicated_lists_within_a_list_of_lists(list_of_lists)
            merged_list = list(list_of_lists[0])
            for a_list in list_of_lists[1::]:
                    for e in a_list:
                        if e not in merged_list:
                            merged_list.append(e)
            return merged_list
        else:
            return list(list_of_lists)
    else:
        raise TypeError("uniquely_merge_list_of_lists(list_of_lists): list_of_list must be a non-empty list")

# %%
def uniquely_merge_multi_dimentional_list_of_lists(multi_dimentional_list_of_lists):
    final_merged_list = uniquely_merge_list_of_lists(multi_dimentional_list_of_lists)
    if type(final_merged_list) == list and len(final_merged_list) > 0 and list_is_type(final_merged_list, list) == True:
        return uniquely_merge_multi_dimentional_list_of_lists(final_merged_list)
    else:
        return final_merged_list

# %%
def elements_match(list_of_lists, lst):
    return set(lst).issubset(uniquely_merge_multi_dimentional_list_of_lists(list_of_lists))

# %%
def get_matching_list(list_of_lists, lst):
    """
    Get any list that match a specified list.
    """
    
    if type(lst) != list:
        raise TypeError("get_matching_list(list_of_lists, lst): lst is not a list object")    
    elif type(list_of_lists) == list and len(list_of_lists) > 0 and list_is_type(list_of_lists, list) == True:
        matching_list = []
        for a_list in list_of_lists:
            if all([x in lst for x in a_list]) == True:
                matching_list.append(a_list)
        return matching_list
    else:
        raise TypeError("get_matching_list(list_of_lists, lst): list_of_lists should be in the form: [[],[],... ]")

# %%
def match_any_list(list_of_lists, lst):
    """
    Check if a list matches any of lists within a list.
    """
            
    if get_matching_list(list_of_lists, lst) == []:
        return False
    else:
        return True

# %%
def search_sbider_path_memory(input_dictionary, activated_paths, from_operon):
    print "~IN search_sbider_path_memory~"
    print
    print
    print
    print "search_sbider_path_memory: activated_paths:", activated_paths
    
    print "search_sbider_path_memory: from_operon:", from_operon, type(from_operon)
    final_operon_requirement = input_dictionary[from_operon]
    
    activated_ope_dic = {}
    activated_spe_dic = {}
    
    for path_idx, ope_spe_path in enumerate(activated_paths):
        activated_ope_dic[path_idx] = ope_spe_path[0] # ope
        activated_spe_dic[path_idx] = ope_spe_path[1] # spe
        
    activating_ope_list = []
    activating_spe_list = []
    
    deletion_counter = 0
    for path_idx, spe_produced in activated_spe_dic.items(): #each spe_path
        for a_spe_produced in spe_produced: #each species in a spe_path
            for and_spe_required in final_operon_requirement: #a required species for activation
                
                if a_spe_produced in and_spe_required:
                    activating_ope_list.extend(activated_ope_dic.get(path_idx))
                    activating_spe_list.extend(activated_spe_dic.get(path_idx))
                    del activated_paths[path_idx - deletion_counter] # do not look at this path idx again
                    deletion_counter = deletion_counter + 1
    
    print "search_sbider_path_memory: activating_ope_list:", activating_ope_list
    print "search_sbider_path_memory: activating_spe_list:", activating_spe_list

    return activating_ope_list, activating_spe_list

# %%
def build_sbider_path_memory_tree(input_dictionary, activated_paths, start_operon, start_species):
    print "~IN build_sbider_path_memory_tree~"
    print
    print
    print
    print "build_sbider_path_memory_tree: activated_paths:", activated_paths
    
    root_ope = node(start_operon) # root of operon tree; ['id']
    root_spe = node(start_species) # root of species tree; [['id','id']]

    temp_queue_ope = [] # for growing ope_tree
    temp_queue_ope.append(root_ope)
    
    temp_queue_spe = [] # for growing spe_tree
    temp_queue_spe.append(root_spe)
        
    while len(activated_paths) > 0 and len(temp_queue_ope) > 0 and len(temp_queue_spe) > 0:
        print "build_sbider_path_memory_tree: activated_paths:", activated_paths
        print "build_sbider_path_memory_tree: temp_queue_ope:", temp_queue_ope
        print "build_sbider_path_memory_tree: temp_queue_spe:", temp_queue_spe
        
        from_node = temp_queue_ope.pop(0)
        from_operon = from_node.value
        species_node = temp_queue_spe.pop(0)
        species_value = species_node.value

        print "build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory"
        children_operon, children_species = search_sbider_path_memory(input_dictionary, activated_paths, from_operon)
        print "build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory"
        if len(children_operon) > 0:
            for child_operon in children_operon:
                child_node = node(child_operon)
                from_node.append_child(child_node)
                temp_queue_ope.append(child_node)
            print "build_sbider_path_memory_tree: ROOT_OPE UPDATED \n", root_ope, type(child_node)
            print "*" * 99
        
        if len(children_species) > 0:
            for child_species in children_species:
                child_node = node(child_species)
                species_node.append_child(child_node)
                temp_queue_spe.append(child_node)
            print "build_sbider_path_memory_tree: ROOT_SPE UPDATED \n", root_spe
            print "*" * 99

    return root_ope.get_path_from_all_leaf(), root_spe.get_path_from_all_leaf()

# %%
def build_indirect_sbider_path(input_dictionary,
                               output_dictionary,
                               input_species_list,
                               output_species_list,
                               path_queue,
                               final_operon_path_list,
                               final_species_path_list,
                               memory_operon,
                               memory_species,
                               species_path_queue,
                               activated_paths):
    print "~IN build_indirect_sbider_path~"
    print
    print
    print
    print "build_indirect_sbider_path: path_queue:", path_queue, len(path_queue)
    print "build_indirect_sbider_path: species_path_queue:", species_path_queue, len(species_path_queue)
    print "build_indirect_sbider_path: memory_operon:", memory_operon 
    print "build_indirect_sbider_path: memory_species:", memory_species
    print "build_indirect_sbider_path: activated_paths:", activated_paths
    
    for an_operon in set(input_dictionary.keys()) - set(memory_operon):
        
        activation_requirement = input_dictionary[an_operon]
        
        if match_any_list(activation_requirement, memory_species) == True:
            
            just_produced_species = output_dictionary[an_operon]
            just_produced_unique_species = uniquely_merge_multi_dimentional_list_of_lists(just_produced_species)            
            
            matched_input_requirement = get_matching_list(activation_requirement, memory_species)
            matched_unique_input_requirement = uniquely_merge_multi_dimentional_list_of_lists(matched_input_requirement)
            
            print "build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree"
            ope_path_backward, spe_path_backward = build_sbider_path_memory_tree(input_dictionary, activated_paths, an_operon, matched_unique_input_requirement)
            print "build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree"
            
            if match_any_list(just_produced_species, output_species_list):
                  
                if not (len(ope_path_backward) > 0 and len(spe_path_backward) > 0):
                    final_operon_path_list.append([an_operon])
                    final_species_path_list.append(just_produced_unique_species)
                else:
                    final_operon_path_list.extend(ope_path_backward)
                    final_species_path_list.extend(spe_path_backward)

            else:
                if an_operon not in memory_operon:
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    
                    # not entire path is included
                    path_queue.append(([an_operon],just_produced_unique_species))
                    species_path_queue.append(just_produced_unique_species)
                    
                    memory_operon.append(an_operon)
                    memory_operon = remove_duplicates_within_list(memory_operon)
                    
                    memory_species.extend(just_produced_unique_species)
                    memory_species = remove_duplicates_within_list(memory_species)
  
                    activated_paths.append([[an_operon],just_produced_unique_species])

    # if there is activated operon, run sbider_path agian.
    if len(path_queue) > 0:
        
        print "build_indirect_sbider_path: ReENTERING--- build_direct_sbider_path"
        build_direct_sbider_path(input_dictionary,
                                 output_dictionary,
                                 input_species_list,
                                 output_species_list,
                                 path_queue,
                                 final_operon_path_list,
                                 final_species_path_list,
                                 memory_operon,
                                 memory_species,
                                 species_path_queue,
                                 activated_paths)

# %%
def build_direct_sbider_path(input_dictionary,
                             output_dictionary,
                             input_species_list,
                             output_species_list,
                             path_queue,
                             final_operon_path_list,
                             final_species_path_list,
                             memory_operon,
                             memory_species,
                             species_path_queue,
                             activated_paths):
    print "~IN build_direct_sbider_path~"
    print
    print
    print
    print "build_direct_sbider_path: path_queue:", path_queue, len(path_queue)
    print "build_direct_sbider_path: species_path_queue:", species_path_queue, len(species_path_queue)
    print "build_direct_sbider_path: memory_operon:", memory_operon 
    print "build_direct_sbider_path: memory_species:", memory_species
    print "build_direct_sbider_path: activated_paths:", activated_paths
    
    while len(path_queue) != 0:
        (previously_visited_operon_list, just_previously_produced_species_list) = path_queue.pop(0)
        previously_visited_species_list = species_path_queue.pop(0)
        for an_operon in set(input_dictionary.keys()) - set(previously_visited_operon_list):
            
            activation_requirement = input_dictionary[an_operon]
            
            if match_any_list(activation_requirement, just_previously_produced_species_list) == True:
                visited_operon_list = previously_visited_operon_list + [an_operon]

                just_produced_species = output_dictionary[an_operon]
                just_produced_unique_species = uniquely_merge_multi_dimentional_list_of_lists(just_produced_species)
                visited_species_list = previously_visited_species_list + just_produced_unique_species
                #visited_species_list = remove_duplicates_within_list(visited_species_list)
                                
                if match_any_list(just_produced_species, output_species_list):
                    final_operon_path_list.append(visited_operon_list)
                    final_species_path_list.append(list(visited_species_list)) #why list(); copy?
                else:        
                    if an_operon not in memory_operon:
                        path_queue.append((visited_operon_list,just_produced_unique_species))
                        species_path_queue.append(visited_species_list)
                        
                        memory_operon.append(an_operon)
                        memory_operon = remove_duplicates_within_list(memory_operon)                        
                        
                        memory_species.extend(just_produced_unique_species)
                        memory_species = remove_duplicates_within_list(memory_species)
               
                        activated_paths.append([[an_operon],just_produced_unique_species])                        
    
    print "build_direct_sbider_path: ENTERING--- build_indirect_sbider_path"
    build_indirect_sbider_path(input_dictionary,
                               output_dictionary,
                               input_species_list,
                               output_species_list,
                               path_queue,
                               final_operon_path_list,
                               final_species_path_list,
                               memory_operon,
                               memory_species,
                               species_path_queue,
                               activated_paths)
    print "build_direct_sbider_path: ---RETURNING build_indirect_sbider_path"
    
    if len(final_operon_path_list) > 0:
         final_operon_path_list = remove_duplicated_lists_within_a_list_of_lists(final_operon_path_list)
    if len(final_species_path_list) > 0:
         final_species_path_list = remove_duplicated_lists_within_a_list_of_lists(final_species_path_list)
    return final_operon_path_list, final_species_path_list

# %%
def get_sbider_path(input_dictionary,
                    output_dictionary,
                    input_species_list,
                    output_species_list):
    print "~IN get_sbider_path~"
    print
    print
    print
    operon_path = []
    spieces_path = []
    
    path_queue = [([],input_species_list)]
    species_path_queue = [input_species_list] # pool of species
    
    memory_operon = []
    memory_species = []
    memory_species.extend(input_species_list)
    
    activated_paths = []
    
    print "get_sbider_path: ENTERING--- build_direct_sbider_path"
,3': [['21']], '73,1': [['39']], '44,1': [['22']], '44,2': [['21']], '29,3': [['27']], '29,2': [['11']], '29,1': [['22']], '93,1': [['5']], '93,2': [['2']], '89,1': [['42']], '89,2': [['21']], '59,1': [['24']], '34,1': [['11']], '48,1': [['26']], '48,2': [['21']], '23,1': [['11']], '23,2': [['27']], '33,2': [['12']], '102,3': [['30']], '33,1': [['6']], '78,1': [['11']], '102,4': [['2']], '78,2': [['21']], '67,1': [['11']], '35,1': [['11']], '35,2': [['2']], '82,2': [['21']], '12,1': [['39']], '82,1': [['39']], '50,1': [['11']], '97,1': [['42']], '54,3': [['43']], '80,3': [['21']], '9,2': [['2', '3']], '9,1': [['22']], '7,1': [['39']], '7,2': [['3', '36']], '56,3': [['9']], '90,2': [['9']], '76,2': [['2']], '99,2': [['9']], '10,2': [['3', '36']], '10,1': [['22']], '99,1': [['23']], '76,1': [['38']], '69,2': [['22', '26']], '69,1': [['9']], '28,2': [['31']], '28,1': [['9']], '72,2': [['21']], '103,1': [['46', '9']], '81,2': [['11']], '88,1': [['42']], '88,2': [['2']], '100,1': [['42']], '56,1': [['43']], '54,2': [['1']], '54,1': [['19']], '56,2': [['19', '22']], '22,1': [['21']], '22,2': [['11', '36']], '14,1': [['35']]}

inp = ['1', '13', '20']
outp = ['5']

# %%
get_sbider_path(input_path_dictionary, output_path_dictionary, inp, outp)
# Out:
# ~IN get_sbider_path~
#
#
#
# get_sbider_path: ENTERING--- build_direct_sbider_path
# ~IN build_direct_sbider_path~
#
#
#
# build_direct_sbider_path: path_queue: [([], ['1', '13', '20'])] 1
# build_direct_sbider_path: species_path_queue: [['1', '13', '20']] 1
# build_direct_sbider_path: memory_operon: []
# build_direct_sbider_path: memory_species: ['1', '13', '20']
# build_direct_sbider_path: activated_paths: []
# build_direct_sbider_path: ENTERING--- build_indirect_sbider_path
# ~IN build_indirect_sbider_path~
#
#
#
# build_indirect_sbider_path: path_queue: [] 0
# build_indirect_sbider_path: species_path_queue: [] 0
# build_indirect_sbider_path: memory_operon: ['81,3', '79,3', '5,2', '3,2', '46,3', '72,1', '91,2', '8,2', '25,1', '37,2', '95,2', '6,2', '74,2', '92,2', '71,1', '98,2', '75,2', '101,5', '101,4', '24,1', '49,2', '96,2', '2,2', '4,2', '102,5', '47,3', '73,4', '29,3', '93,2', '89,2', '48,2', '23,2', '33,2', '102,4', '78,2', '82,2', '80,3', '9,2', '7,2', '90,2', '76,2', '99,2', '10,2', '69,1', '35,2', '28,1', '88,2', '34,1']
# build_indirect_sbider_path: memory_species: ['1', '13', '20', '21', '2', '36', '9', '11', '3', '27', '12']
# build_indirect_sbider_path: activated_paths: [[['81,3'], ['21']], [['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['49,2'], ['21']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['102,5'], ['21']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['89,2'], ['21']], [['48,2'], ['21']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['78,2'], ['21']], [['82,2'], ['21']], [['80,3'], ['21']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree
# ~IN build_sbider_path_memory_tree~
#
#
#
# build_sbider_path_memory_tree: activated_paths: [[['81,3'], ['21']], [['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['49,2'], ['21']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['102,5'], ['21']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['89,2'], ['21']], [['48,2'], ['21']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['78,2'], ['21']], [['82,2'], ['21']], [['80,3'], ['21']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: activated_paths: [[['81,3'], ['21']], [['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['49,2'], ['21']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['102,5'], ['21']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['89,2'], ['21']], [['48,2'], ['21']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['78,2'], ['21']], [['82,2'], ['21']], [['80,3'], ['21']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['19,2'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: [['20', '21']
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['81,3'], ['21']], [['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['49,2'], ['21']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['102,5'], ['21']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['89,2'], ['21']], [['48,2'], ['21']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['78,2'], ['21']], [['82,2'], ['21']], [['80,3'], ['21']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 19,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: ['81,3', '49,2', '102,5', '89,2', '48,2', '78,2', '82,2', '80,3']
# search_sbider_path_memory: activating_spe_list: ['21', '21', '21', '21', '21', '21', '21', '21']
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: ROOT_OPE UPDATED
# '19,2'
# 	'81,3'
# 	'49,2'
# 	'102,5'
# 	'89,2'
# 	'48,2'
# 	'78,2'
# 	'82,2'
# 	'80,3'
#  <class '__main__.node'>
# ***************************************************************************************************
# build_sbider_path_memory_tree: ROOT_SPE UPDATED
# ['20', '21']
# 	'21'
#
# ***************************************************************************************************
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['81,3'
# , '49,2'
# , '102,5'
# , '89,2'
# , '48,2'
# , '78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 81,3 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['49,2'
# , '102,5'
# , '89,2'
# , '48,2'
# , '78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 49,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['102,5'
# , '89,2'
# , '48,2'
# , '78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# , '21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 102,5 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['89,2'
# , '48,2'
# , '78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 89,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['48,2'
# , '78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 48,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['78,2'
# , '82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 78,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['82,2'
# , '80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# , '21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 82,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['80,3'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['21'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 80,3 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree
# build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree
# ~IN build_sbider_path_memory_tree~
#
#
#
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']]]
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['81,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: [['20', '21']
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']]]
# search_sbider_path_memory: from_operon: 81,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree
# build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree
# ~IN build_sbider_path_memory_tree~
#
#
#
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']], [['81,1'], ['22']]]
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']], [['81,1'], ['22']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['19,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: [['22']
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,2'], ['22']], [['81,1'], ['22']]]
# search_sbider_path_memory: from_operon: 19,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: ['19,2', '81,1']
# search_sbider_path_memory: activating_spe_list: ['22', '22']
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: ROOT_OPE UPDATED
# '19,1'
# 	'19,2'
# 	'81,1'
#  <class '__main__.node'>
# ***************************************************************************************************
# build_sbider_path_memory_tree: ROOT_SPE UPDATED
# ['22']
# 	'22'
#
# ***************************************************************************************************
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['19,2'
# , '81,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['22'
# , '22'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 19,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['81,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['22'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']]]
# search_sbider_path_memory: from_operon: 81,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree
# build_indirect_sbider_path: ENTERING--- build_sbider_path_memory_tree
# ~IN build_sbider_path_memory_tree~
#
#
#
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['51,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: [['13', '2', '20', '21']
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['79,3'], ['2']], [['5,2'], ['2', '36']], [['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['8,2'], ['2', '36']], [['25,1'], ['9']], [['37,2'], ['2']], [['95,2'], ['36']], [['6,2'], ['2', '3']], [['74,2'], ['2']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['75,2'], ['2']], [['101,5'], ['36']], [['101,4'], ['9']], [['24,1'], ['2']], [['96,2'], ['2']], [['2,2'], ['2']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['93,2'], ['2']], [['23,2'], ['27']], [['33,2'], ['12']], [['102,4'], ['2']], [['9,2'], ['2', '3']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['76,2'], ['2']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['35,2'], ['2']], [['28,1'], ['9']], [['88,2'], ['2']], [['34,1'], ['11']], [['19,1'], ['11']]]
# search_sbider_path_memory: from_operon: 51,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: ['79,3', '5,2', '8,2', '37,2', '6,2', '74,2', '75,2', '24,1', '96,2', '2,2', '93,2', '102,4', '9,2', '76,2', '35,2', '88,2']
# search_sbider_path_memory: activating_spe_list: ['2', '2', '36', '2', '36', '2', '2', '3', '2', '2', '2', '2', '2', '2', '2', '2', '3', '2', '2', '2']
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: ROOT_OPE UPDATED
# '51,1'
# 	'79,3'
# 	'5,2'
# 	'8,2'
# 	'37,2'
# 	'6,2'
# 	'74,2'
# 	'75,2'
# 	'24,1'
# 	'96,2'
# 	'2,2'
# 	'93,2'
# 	'102,4'
# 	'9,2'
# 	'76,2'
# 	'35,2'
# 	'88,2'
#  <class '__main__.node'>
# ***************************************************************************************************
# build_sbider_path_memory_tree: ROOT_SPE UPDATED
# ['13', '2', '20', '21']
# 	'2'
# 	'36'
# 	'3'
#
# ***************************************************************************************************
# build_sbider_path_memory_tree: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['79,3'
# , '5,2'
# , '8,2'
# , '37,2'
# , '6,2'
# , '74,2'
# , '75,2'
# , '24,1'
# , '96,2'
# , '2,2'
# , '93,2'
# , '102,4'
# , '9,2'
# , '76,2'
# , '35,2'
# , '88,2'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['2'
# , '2'
# , '36'
# , '2'
# , '36'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# search_sbider_path_memory: from_operon: 79,3 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['5,2'
# , '8,2'
# , '37,2'
# , '6,2'
# , '74,2'
# , '75,2'
# , '24,1'
# , '96,2'
# , '2,2'
# , '93,2'
# , '102,4'
# , '9,2'
# , '76,2'
# , '35,2'
# , '88,2'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['2'
# , '36'
# , '2'
# , '36'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# search_sbider_path_memory: from_operon: 5,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['8,2'
# , '37,2'
# , '6,2'
# , '74,2'
# , '75,2'
# , '24,1'
# , '96,2'
# , '2,2'
# , '93,2'
# , '102,4'
# , '9,2'
# , '76,2'
# , '35,2'
# , '88,2'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['36'
# , '2'
# , '36'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# search_sbider_path_memory: from_operon: 8,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['37,2'
# , '6,2'
# , '74,2'
# , '75,2'
# , '24,1'
# , '96,2'
# , '2,2'
# , '93,2'
# , '102,4'
# , '9,2'
# , '76,2'
# , '35,2'
# , '88,2'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: ['2'
# , '36'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '2'
# , '3'
# , '2'
# , '2'
# , '2'
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# search_sbider_path_memory: from_operon: 37,2 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_sbider_path_memory_tree: activated_paths: [[['3,2'], ['36']], [['46,3'], ['9']], [['72,1'], ['11', '36']], [['91,2'], ['36']], [['25,1'], ['9']], [['95,2'], ['36']], [['92,2'], ['36']], [['71,1'], ['36']], [['98,2'], ['36']], [['101,5'], ['36']], [['101,4'], ['9']], [['4,2'], ['3']], [['47,3'], ['9']], [['73,4'], ['36']], [['29,3'], ['27']], [['23,2'], ['27']], [['33,2'], ['12']], [['7,2'], ['3', '36']], [['90,2'], ['9']], [['99,2'], ['9']], [['10,2'], ['3', '36']], [['69,1'], ['9']], [['28,1'], ['9']], [['34,1'], ['11']], [['19,1'], ['11']]]
# build_sbider_path_memory_tree: temp_queue_ope: 
# build_sbider_path_memory_tree: activated_paths: [[['33,2'], ['12']], [['34,1'], ['11']], [['19,1'], ['11']], [['1,1'], ['11']], [['79,2'], ['11']], [['5,1'], ['39']], [['46,2'], ['11']], [['72,3'], ['39']], [['15,1'], ['11']], [['25,2'], ['11']], [['104,1'], ['14']], [['37,1'], ['7']], [['31,2'], ['11']], [['12,1'], ['39']], [['80,2'], ['11']], [['43,1'], ['17']], [['101,3'], ['23']], [['24,2'], ['11']], [['18,1'], ['11']], [['49,1'], ['42']], [['58,1'], ['14']], [['55,2'], ['43']], [['13,1'], ['40']], [['2,1'], ['39']], [['20,2'], ['36']], [['47,2'], ['42']], [['17,1'], ['11']], [['73,1'], ['39']], [['29,2'], ['11']], [['89,1'], ['42']], [['59,1'], ['24']], [['48,1'], ['26']], [['23,1'], ['11']], [['78,1'], ['11']], [['35,1'], ['11']], [['6,1'], ['39']], [['82,1'], ['39']], [['50,1'], ['11']], [['97,1'], ['42']], [['56,1'], ['43']], [['99,1'], ['23']], [['76,1'], ['38']], [['28,2'], ['31']], [['81,2'], ['11']], [['88,1'], ['42']], [['54,3'], ['43']], [['22,2'], ['11', '36']], [['14,1'], ['35']], [['90,1'], ['42']]]
# build_sbider_path_memory_tree: temp_queue_ope: ['93,1'
# ]
# build_sbider_path_memory_tree: temp_queue_spe: [['13', '2']
# ]
# build_sbider_path_memory_tree: ENTERING--- search_sbider_path_memory
# ~IN search_sbider_path_memory~
#
#
#
# search_sbider_path_memory: activated_paths: [[['33,2'], ['12']], [['34,1'], ['11']], [['19,1'], ['11']], [['1,1'], ['11']], [['79,2'], ['11']], [['5,1'], ['39']], [['46,2'], ['11']], [['72,3'], ['39']], [['15,1'], ['11']], [['25,2'], ['11']], [['104,1'], ['14']], [['37,1'], ['7']], [['31,2'], ['11']], [['12,1'], ['39']], [['80,2'], ['11']], [['43,1'], ['17']], [['101,3'], ['23']], [['24,2'], ['11']], [['18,1'], ['11']], [['49,1'], ['42']], [['58,1'], ['14']], [['55,2'], ['43']], [['13,1'], ['40']], [['2,1'], ['39']], [['20,2'], ['36']], [['47,2'], ['42']], [['17,1'], ['11']], [['73,1'], ['39']], [['29,2'], ['11']], [['89,1'], ['42']], [['59,1'], ['24']], [['48,1'], ['26']], [['23,1'], ['11']], [['78,1'], ['11']], [['35,1'], ['11']], [['6,1'], ['39']], [['82,1'], ['39']], [['50,1'], ['11']], [['97,1'], ['42']], [['56,1'], ['43']], [['99,1'], ['23']], [['76,1'], ['38']], [['28,2'], ['31']], [['81,2'], ['11']], [['88,1'], ['42']], [['54,3'], ['43']], [['22,2'], ['11', '36']], [['14,1'], ['35']], [['90,1'], ['42']]]
# search_sbider_path_memory: from_operon: 93,1 <type 'str'>
# search_sbider_path_memory: activating_ope_list: []
# search_sbider_path_memory: activating_spe_list: []
# build_sbider_path_memory_tree: ---RETURNING search_sbider_path_memory
# build_indirect_sbider_path: ---RETURNING build_sbider_path_memory_tree
# build_direct_sbider_path: ---RETURNING build_indirect_sbider_path
# build_direct_sbider_path: ---RETURNING build_indirect_sbider_path
# get_sbider_path: ---RETURNING build_direct_sbider_path
# get_sbider_path: operon_path: [['102,1'], ['93,1']]
# get_sbider_path: spieces_path: [['5']]
# ([['102,1'], ['93,1']], [['5']])
