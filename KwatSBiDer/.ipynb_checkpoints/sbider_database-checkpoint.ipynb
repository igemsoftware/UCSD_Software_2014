# %%
import sqlite3
import subprocess
import math
import pandas as pd
import itertools as it

# %% [markdown]
# # (helper methods)

# %%
def extend_list_of_lists(list_of_lists):
    """Extend lists within a list."""
    
    extended_list = []
    for lst in list_of_lists:
        extended_list.extend(lst)
    return list(set(extended_list))
def format_values(value_list):
    """Convert list values into accessible types."""
    formatted_value_list = []
    for value in value_list:
        if isinstance(value, unicode):
            
            #print 'value unicode (before):', value
            
            formatted_value_list.append(str(value))
            
            #print 'value unicode (before):', value
            
        elif math.isnan(value):
            
            #print 'value nan (before):', value
            
            formatted_value_list.append("na")
            
            #print 'value nan (after):', value
            
            
            
            '''elif isinstance(value, float):
            #print 'float changer b', item
            formmatted_value_list.append(int(item))
            #print 'float changer a', item'''
        
        
        
        else:
            formatted_value_list.append(value)
            
    #print 'formatted_value_list:', formatted_value_list 
    
    return formatted_value_list

# %% [markdown]
# # Access sbider.db

# %% [markdown]
# ### Methods for connecting and closing sbider.db

# %%
def db_open(database_file):
    '''Connect to a database or create a database if it does not already
    exist.'''
    
    connection = sqlite3.connect(database_file)
    connection.text_factory = str
    cursor = connection.cursor()
    
    return connection, cursor

# %%
def db_close(connection, cursor):
    """Close a database."""
    
    connection.commit()
    cursor.close()

# %% [markdown]
# ### Connect and close sbider.db

# %%
conn, cur = db_open("sbider.db")
print "conn, cur:", conn, cur
# Out:
# conn, cur: <sqlite3.Connection object at 0x106a7e2e8> <sqlite3.Cursor object at 0x1069fee30>

# %% [markdown]
# db_close(conn, cur)

# %% [markdown]
# # Make SQL commands for sbider.db

# %%
def make_sql_insert_command(table_name, table_header_list, insert_data_list):
    '''Make SQL insert command.'''
    
    ###print "insert_data_list:", insert_data_list
    
    insert_data_list_formatted = list(insert_data_list)
    
    ###print "insert_data_list_formatted:", insert_data_list_formatted
    
    sql_insert_into = 'INSERT INTO ' + table_name
    
    ###print "sql_insert_into:", sql_insert_into
    
    sql_insert_header = '(' + ','.join(table_header_list) + ')'
    
    ###print "sql_insert_header:", sql_insert_header
    
    for index in range(len(insert_data_list_formatted)):

        if isinstance(insert_data_list_formatted[index], str):
            insert_data_list_formatted[index] = "'" + insert_data_list_formatted[index] + "'"  
                
        else:
            insert_data_list_formatted[index] = str(insert_data_list_formatted[index])      
                                            
    sql_values = 'Values (' + ','.join(insert_data_list_formatted) + ')'
    
    ###print "sql_values:", sql_values
    
    sql_insert_command = sql_insert_into + '\n\t' + sql_insert_header + '\n\t' + sql_values + ';'
    
    ###print "sql_command:", sql_command
    
    return sql_insert_command

# %%
def make_sql_select_command(table_name, table_header_list, where_columns = None, where_options = None,
    where_values = None, where_bools = None, group = None, having_columns = None, having_bools = None, 
    having_values = None):
    '''Make SQL select command.
    
    @param table_header_list - list of columns to be selected
    @param where_columns - column names for where clause
    @param where_options - operator for where clause
    @param where_values - variable for where clause 
    @param where_bools - boolean for where clause
    @param group - group name for GROUP BY caluse
    @param having_columns'''
    
    # check whether argument is valid or not
    # all the where_variables must be all None or same size where_bool is less by 1
    if (where_columns is not None and where_options is not None and where_values is not None \
        and where_bools is not None):
        if (len(where_columns) != len(where_options) and len(where_options) != len(where_values)\
            and len(where_values) != (len(where_bools) - 1)):
            raise Exception("Invalid argument")
    elif(where_columns is not None or where_options is not None or where_values is not None \
         or where_bools is not None):
            raise Exception("Invalid argument")

    # must have a table name
    if ( table_name is None or len(table_name) == 0):
        raise Exception("a table name must be provided.")

    sql_select_command = "SELECT "
    
    for table_header_index in range(len(table_header_list)):
        sql_select_command += table_header_list[table_header_index]
        if (table_header_index != len(table_header_list) - 1):
            sql_select_command += ", "
        else:
            sql_select_command += " "
    sql_select_command += "\n" + "FROM " + table_name + " "

    if where_columns is not None :
        sql_select_command += "\n"+"WHERE "
        for where_index in range(len(where_columns)):
            
            ###print "where_index:", where_index
            
            sql_select_command += where_columns[where_index] + " " + where_options[where_index] + " " + str(where_values[where_index]) + " "
            if where_index < len(where_bools):
                sql_select_command += where_bools[where_index] + " "

    if group is not None:
        sql_select_command += "\n" + "GROUP BY " + group
        
    if having_columns is not None and having_bools is not None and having_values is not None:
        sql_select_command += "\n" + "HAVING " + having_columns + " " +  having_bools + " " + str(having_values)
    sql_select_command +=";"
        
    return sql_select_command

# %%
def make_sql_update_command(table_name, table_header_list, update_data_list, where_column = "", 
                            where_option = "", where_value = ""):
    """Makes SQL update command
    @param table_name - Updating table
    @param table_header_list - Selected columns
    @param where_columns - Where column names
    @param where_options - List of operators
    @param where_values - variable for where clause 
    @param where_bools - boolean for where clause"""
    
    sql_update = 'UPDATE ' + table_name
    
    update_values_list = []
    for column_name, update_value in zip(table_header_list, update_data_list):
        #print "column_name, update_value:", column_name, update_value
        update_values_list.append(str(column_name) + ' = ' + str(update_value))
        
    ###print "\nfilled update_values_list:", update_values_list
    '''for item in update_values_list:
        print item
    '''
        
    sql_update_values = 'SET ' + ', '.join(update_values_list)
    
    ###print "\nsql_update_values:", sql_update_values
    '''for item in sql_update_values:
        print item
    '''
    
    sql_where = ""
    if where_column != "":
        sql_where = "\n" + " ".join(['WHERE', where_column, where_option, where_value])
    
    '''for where_column_name, where_value , where_op, index in 
            zip(where_columns, where_values, where_options, range(len(where_columns) + 1)):
            if i < len(where_columns) - 1:
                hold = sql_where + ' '.join([where_column_name,where_option,str(where_value)]) + ' ' + w_conts[index]
            else:
                hold = sql_where + ' '.join([where_column_name,where_option,str(where_value)]) + ' ' 
            sql_where = hold 
        return update_command + '\n\t' + set_str + '\n\t' + where_str + ';'''
    
    
    sql_update_command  = sql_update + "\n" + sql_update_values + sql_where + ";"
    
    ###print "update_command:\n", sql_update_command
    
    return sql_update_command

# %%
def make_sql_delete_command(table_name):
    sql_delete_command = "DELETE FROM %s;" % table_name
    return sql_delete_command

# %%
def make_sql_drop_command(table_name):
    
    sql_drop_command = "DROP TABLE %s;" % table_name
    
    return sql_drop_command

# %% [markdown]
# # Build sbider.db

# %% [markdown]
# ### Methods for creating and dropping tables for sbider.db

# %%
def db_create_table(cursor):
    """Make tables for sbider.db"""

    species = '''CREATE TABLE Species (spe_id VARCHAR(50), 
                                       name VARCHAR(50), 
                                       type VARCHAR(50));'''
    
    plasmid = '''CREATE TABLE Plasmid (pla_id VARCHAR(50), 
                                       name VARCHAR(50), 
                                       miriam_id VARCHAR(50));'''
    
    operon = '''CREATE TABLE Operon (ope_id VARCHAR(50), 
                                     name VARCHAR(50),
                                     image VARCHAR(50));'''
    
    po = '''CREATE TABLE PlasmidOperon (ope_id VARCHAR(50), 
                                        pla_id VARCHAR(50),
                                        direction VARCHAR(50));'''
    
    oit = '''CREATE TABLE OperonInputTransition (it_id VARCHAR(50), 
                                                 ope_id VARCHAR(50));'''
    
    it = '''CREATE TABLE InputTransition (it_id VARCHAR(50), 
                                          logic VARCHAR(50));'''
    
    in_ = '''CREATE TABLE InputTransitionSpecies (in_id VARCHAR(50), 
                                                  it_id VARCHAR(50), 
                                                  spe_id VARCHAR(50),
                                                  reverse BOOL);'''
    
    oot = '''CREATE TABLE OperonOutputTransition (ot_id VARCHAR(50),
                                                  ope_id VARCHAR(50));'''
    
    ot = '''CREATE TABLE OutputTransition (ot_id VARCHAR(50), 
                                           logic VARCHAR(50))'''
    
    out = '''CREATE TABLE OutputTransitionSpecies (out_id VARCHAR(50), 
                                                   ot_id VARCHAR(50),
                                                   spe_id VARCHAR(50));'''
    
    login = '''CREATE TABLE User (user_id VARCHAR(50), 
                                  first_name VARCHAR(50),
                                  last_name VARCHAR(50),
                                  email VARCHAR(50),
                                  password VARCHAR(50));'''
    
    table_list =[species,plasmid, 
                 operon, 
                 po, 
                 oit, 
                 it, 
                 in_, 
                 oot, 
                 ot, 
                 out, 
                 login]
    
    for table in table_list:        
        cursor.execute(table)
        
    return cursor

# %%
def db_drop_table(cursor, table_name):
    """Drop a table."""
    
    sql_drop_command = make_sql_drop_command(table_name)
    
    cursor.execute(sql_drop_command)
    
    return cursor

# %%
def db_drop_all_table(cursor):
    """Drop all tables."""
    
    table_name_list = ["Species", 
                       "Plasmid", 
                       "Operon", 
                       "PlasmidOperon", 
                       "OperonInputTransition", 
                       "InputTransition", 
                       "InputTransitionSpecies", 
                       "OperonOutputTransition", 
                       "OutputTransition", 
                       "OutputTransitionSpecies", 
                       "User"]
    
    ###print "table_name_list", table_name_list
    
    for table_name in table_name_list:
        
        sql_drop_command = make_sql_drop_command(table_name)
    
        cursor.execute(sql_drop_command)
    
    return cursor

# %% [markdown]
# ### Create and drop tables for sbider.db

# %%
db_create_table(cur)

# %% [markdown]
# db_drop_all_table(cur)

# %% [markdown]
# # Use sbider table

# %% [markdown]
# ### Methods for using sbider.db

# %%
def db_print_table(cursor, table_name):
    """Print a table."""
    
    cursor.execute("SELECT * FROM " + table_name)
    rows = cursor.fetchall()
    for row in rows:
        print row

# %%
def db_print_all_table(cursor):
    """Print all table."""
    
    db_print_table(cursor, "Species")
    db_print_table(cursor, "Plasmid")
    db_print_table(cursor, "Operon")
    db_print_table(cursor, "PlasmidOperon")
    db_print_table(cursor, "OperonInputTransition")
    db_print_table(cursor, "InputTransition")
    db_print_table(cursor, "InputTransitionSpecies")
    db_print_table(cursor, "OperonOutputTransition")
    db_print_table(cursor, "OutputTransition")
    db_print_table(cursor, "OutputTransitionSpecies")
    db_print_table(cursor, "User")

# %%
def db_get_species_id_from_name(cursor, species_name):
    a_cur = db_select(cursor, 
                      "Species",
                      ["spe_id"], 
                      ["name"], 
                      ["="], 
                      ["'%s'" % species_name.lower()], 
                      "")
    return a_cur.fetchone()[0]

# %%
def db_get_name_id_from_id(cursor, species_id):
    a_cur = db_select(cursor, 
                     "Species",
                     ["name"], 
                     ["spe_id"], 
                     ["="], 
                     [species_id], 
                     "")
    return a_cur.fetchone()[0]

# %%
def db_get_operon_id_from_name(cursor, operon_name):
   a_cur = db_select(cursor, 
                     "Operon",
                     ["ope_id"], 
                     ["name"], 
                     ["="], 
                     ["'%s'" % operon_name], 
                     "")
   return a_cur.fetchone()[0]

# %%
def db_get_operon_name_from_id(cursor, operon_id):
   a_cur = db_select(cursor, 
                    "Operon",
                    ["name"], 
                    ["ope_id"], 
                    ["="], 
                    [operon_id], 
                    "")
   return a_cur.fetchone()[0]

# %%
def db_get_plasmid_id_from_name(cursor, plasmid_name):
   a_cur = db_select(cursor, 
                     "Plasmid",
                     ["pla_id"], 
                     ["name"], 
                     ["="], 
                     ["'%s'" % plasmid_name.lower()], 
                     "")
   return a_cur.fetchone()[0]

# %%
def db_get_plasmid_name_from_id(cursor, plasmid_id):
   a_cur = db_select(cursor, 
                    "Plasmid",
                    ["name"], 
                    ["pla_id"], 
                    ["="], 
                    [plasmid_id], 
                    "")
   return a_cur.fetchone()[0]

# %% [markdown]
# # Modify sbider.db

# %% [markdown]
# ### Methods for modifying tables for sbider.db

# %%
def db_select(cursor, table_name, table_header_list, where_columns = None, where_options = None,
    where_values = None,where_bools = None, group = None, having_columns = None, having_bools = None, 
    having_values = None):
    """Select from a table.
    Args:
        table_name: table you wish to pull data from
        col_names: list of numbers indexing the table columns
        w_col: column names for where clause
        w_opt: operator for where clause
        w_var: variable for where clause 
        w_bool: boolean for where clause
        group: group name for GROUP BY caluse
        h_col: group specifier
    """
    
    sql_command = make_sql_select_command(table_name, table_header_list, where_columns, where_options,
    where_values,where_bools, group, having_columns, having_bools, having_values)
    
    ###print "db_select(...) sql_command:", sql_command
    
    cursor.execute(sql_command)
    
    return cursor

# %%
def db_insert(cursor, table_name, table_header_list, insert_data_list):
    """Insert into a table.
    
    Args:
        table_name, that table that you wish to insert into
        cols, the columns that you want to insert into
        new_row, the values that correspond to the columns
    
    Examples:
        ex 1. Inserting into plasmid table and filling in all the columns. 
    """
    
    sql_command = make_sql_insert_command(table_name, table_header_list, insert_data_list)
    
    ###print "db_insert(...) sql_command", sql_command
    
    cursor.execute(sql_command)
    
    return cursor

# %%
def db_update(cursor, table_name, table_header_list, update_data_list, 
    where_column = "", where_option = "", where_value = ""):
    """Update."""
    
    sql_command = make_sql_update_command(table_name, table_header_list, update_data_list, 
        where_column, where_option, where_value)
    
    print "sql_command:", sql_command
    
    cursor.execute(sql_command)
    
    return cursor

# %%
def db_delete(cursor, table_name):
    cursor.execute(make_sql_delete_command(table_name))

# %%
def db_custom(cursor, sql_command):
    """Do whatever."""
    cursor.execute(sql_command)
    
    return cursor

# %% [markdown]
# # Populate sbider.db

# %% [markdown]
# ### Acess soruce data

# %%
source_data = pd.io.excel.read_excel(
"/Users/K/Dropbox/Project/20140601_sbider/UCSD_iGEM/KwatSBiDer/sbider_database_linh.xlsx",'database')

# %% [markdown]
# ### Populate table Species

# %%
def db_populate_species(cursor, sbider_data):
    
    db_delete(cursor, "Species")
    
    domain = sbider_data[['Domain']]
    range_ = sbider_data[['Range']]
    
    ###print "domain:\n\n", domain
    ###print "range_:\n\n", range_
    ###print "domain list\n:", domain.values.T.tolist()[0]
    ###print "range list\n:", range_.values.T.tolist()[0]
    
    species = set(domain.values.T.tolist()[0] + range_.values.T.tolist()[0])
    
    ###print "species:\n\n", species
        
    inserted_species_set = set([])
    
    count = 1
    
    for row in species:
        
        ###print "row:", row
        
        row = format_values([row])
        
        ###print "row after format:", row
        ###print "row[0]:",row[0]
        
        # list to string, and split by comma
        split_row = row[0].split(',')
        
        ###print "split_row:", split_row

        for spe in split_row:
            stripped_lower_species = spe.strip().lower()

            if inserted_species_set not in inserted_species_set:
                
                db_insert(cursor, 'Species', ['spe_id', 'name'], [count, stripped_lower_species])

                ###print "spe_id   spe_name:\t",count," ", stripped_lower_species
                ###print "inserted_species_set:", inserted_species_set

                inserted_species_set.add(stripped_lower_species)

                ###print "inserted_species_set:", inserted_species_set

                count = count + 1

# %%
db_populate_species(cur, source_data)

# %%
db_print_table(cur, "Species")
# Out:
# ('1', 'na', None)
# ('2', 'arac', None)
# ('3', 'lasr', None)
# ('4', 'ivnf', None)
# ('5', 'sica', None)
# ('6', 'supd', None)
# ('7', 't7ptag', None)
# ('8', 'atc', None)
# ('9', 'luxr', None)
# ('10', 'pai-2', None)
# ('11', 'gfp', None)
# ('12', 'nahr', None)
# ('13', 'arac', None)
# ('14', 'lara', None)
# ('15', 'laczalpha-ccdb', None)
# ('16', 'lexa', None)
# ('17', 't7-n', None)
# ('18', 'luxr', None)
# ('19', 'eyfp', None)
# ('20', 'invf', None)
# ('21', 'ahl', None)
# ('22', 'luxr', None)
# ('23', 'ahl', None)
# ('24', 'notlight', None)
# ('25', 'luxr', None)
# ('26', 'iptg', None)
# ('27', 'laci', None)
# ('28', 'ci', None)
# ('29', 'exsc', None)
# ('30', 'ahl', None)
# ('31', 'ci', None)
# ('32', 'supd', None)
# ('33', 'ccda', None)
# ('34', 'inv', None)
# ('35', 'ahl', None)
# ('36', 'luxr', None)
# ('37', 'ecfp', None)
# ('38', 'laciq', None)
# ('39', 'exsda', None)
# ('40', 'laci', None)
# ('41', 'luxr', None)
# ('42', 'ci', None)
# ('43', 'gfp', None)
# ('44', 't7ptag', None)
# ('45', 'ipgc', None)
# ('46', 'mxie', None)
# ('47', 'iptg', None)
# ('48', 'laciq', None)
# ('49', 'lasr', None)
# ('50', 'hrpr', None)
# ('51', 'hrps', None)
# ('52', 'luxr', None)
# ('53', 'ohhl', None)
# ('54', 't7', None)
# ('55', 'rhll', None)
# ('56', 'tetr', None)
# ('57', 'ahl', None)
# ('58', 'notlight', None)
# ('59', 't7-n', None)
# ('60', 't7-c', None)
# ('61', 'atc', None)
# ('62', 'tetr', None)
# ('63', 'ahl', None)
# ('64', 'laci', None)
# ('65', 't7-c', None)
# ('66', 'yfp', None)
# ('67', 'ipgc', None)
# ('68', 'lasi', None)
# ('69', 'hrpr', None)
# ('70', 'ci', None)
# ('71', 'ecfp', None)
# ('72', 'notlight', None)
# ('73', 'rfp', None)
# ('74', 'atc', None)
# ('75', 'tetr', None)
# ('76', 'beta-galactosidase', None)
# ('77', 'tetr', None)
# ('78', 'gfp', None)
# ('79', 'sal', None)
# ('80', 'lasr', None)
# ('81', 'pai-1', None)
# ('82', 'arac', None)
# ('83', 'tetr', None)
# ('84', 'ahl', None)
# ('85', 'mxie', None)
# ('86', 'arac', None)
# ('87', 'sica', None)
# ('88', 'luxr', None)
# ('89', 'luxi', None)
# ('90', 'laci', None)
# ('91', 'ahl', None)
# ('92', 'atc', None)
# ('93', 'mg2+', None)
# ('94', 'notlight', None)
# ('95', 'pcb', None)
# ('96', 'exsc', None)
# ('97', 'exsda', None)
# ('98', 'tetr', None)
# ('99', 'lasr', None)

# %% [markdown]
# ### Populate table Plasmid

# %%
def db_populate_plasmid(cursor, sbider_data):
    
    db_delete(cursor, "Plasmid")

    p_id_p_name = sbider_data[['P_ID','P_Name']]

    ###print "p_id_p_name:\n\n", p_id_p_name

    p_id_p_name_lists = p_id_p_name.values.T.tolist()
    
    ###print "p_id_p_name_lists:\n", p_id_p_name_lists

    p_id_p_name_list = [row for row in it.izip(*p_id_p_name_lists)]

    ###print "p_id_p_name_list:\n", p_id_p_name_list

    inserted_plasmid_set = set([])
    for row in p_id_p_name_list:
        row = format_values(row)
        
        print "row:", row
        
        if row[0] not in inserted_plasmid_set:

            ###print "pla_id   pla_name:\t", row[0], " ", row[1]

            db_insert(cursor, 'Plasmid', ['pla_id', 'name'], [row[0], row[1].lower()])
            inserted_plasmid_set.add(row[0])

# %%
db_populate_plasmid(cur, source_data)
# Out:
# row: [1, 'P(luxI-lacO)-GFPmut2']
# row: [1, 'P(luxI-lacO)-GFPmut2']
# row: [1, 'P(luxI-lacO)-GFPmut2']
# row: [2, 'pOR10']
# row: [2, 'pOR10']
# row: [2, 'pOR10']
# row: [3, 'pOR20']
# row: [3, 'pOR20']
# row: [3, 'pOR20']
# row: [4, 'pOR30']
# row: [4, 'pOR30']
# row: [4, 'pOR30']
# row: [5, 'pOR1020']
# row: [5, 'pOR1020']
# row: [5, 'pOR1020']
# row: [5, 'pOR1020']
# row: [6, 'pOR1030']
# row: [6, 'pOR1030']
# row: [6, 'pOR1030']
# row: [6, 'pOR1030']
# row: [7, 'pOR2030']
# row: [7, 'pOR2030']
# row: [7, 'pOR2030']
# row: [7, 'pOR2030']
# row: [8, 'pNOR1020']
# row: [8, 'pNOR1020']
# row: [8, 'pNOR1020']
# row: [8, 'pNOR1020']
# row: [9, 'pNOR1030']
# row: [9, 'pNOR1030']
# row: [9, 'pNOR1030']
# row: [9, 'pNOR1030']
# row: [10, 'pNOR2030']
# row: [10, 'pNOR2030']
# row: [10, 'pNOR2030']
# row: [10, 'pNOR2030']
# row: [12, 'pcI-yfp']
# row: [13, 'pcI-lasI']
# row: [14, 'pcI-rhlI']
# row: [15, 'pMKN7a']
# row: [16, 'pBAG102,pBAG103']
# row: [17, 'pBRT21.1,pBRT123,pBRT124,pBRT125']
# row: [18, 'pTAK102,pTAK103a']
# row: [18, 'pTAK102,pTAK103a']
# row: [18, 'pTAK102,pTAK103a']
# row: [19, 'pTAK106,pTAK107']
# row: [19, 'pTAK106,pTAK107']
# row: [19, 'pTAK106,pTAK107']
# row: [20, 'pIKE108, pIKE110']
# row: [20, 'pIKE108, pIKE110']
# row: [20, 'pIKE108, pIKE110']
# row: [21, 'pTAK117, pTAK130, pTAK131, pTAK132']
# row: [21, 'pTAK117, pTAK130, pTAK131, pTAK132']
# row: [21, 'pTAK117, pTAK130, pTAK131, pTAK132']
# row: [22, 'pIKE105, pIKE107']
# row: [22, 'pIKE105, pIKE107']
# row: [22, 'pIKE105, pIKE107']
# row: [23, 'pBW10xlac-gfp']
# row: [23, 'pBW10xlac-gfp']
# row: [23, 'pBW10xlac-gfp']
# row: [24, 'pBW20xara-gfp']
# row: [24, 'pBW20xara-gfp']
# row: [24, 'pBW20xara-gfp']
# row: [25, 'pBW30xlux-gfp']
# row: [25, 'pBW30xlux-gfp']
# row: [25, 'pBW30xlux-gfp']
# row: [28, 'pBW313lux-hrpR']
# row: [28, 'pBW313lux-hrpR']
# row: [28, 'pBW313lux-hrpR']
# row: [29, 'PBW12xlac-cIgfp']
# row: [29, 'PBW12xlac-cIgfp']
# row: [29, 'PBW12xlac-cIgfp']
# row: [29, 'PBW12xlac-cIgfp']
# row: [30, 'pBW400hrpL-gfp']
# row: [31, 'PBW412hrpL-cIgfp']
# row: [31, 'PBW412hrpL-cIgfp']
# row: [31, 'PBW412hrpL-cIgfp']
# row: [33, 'pAC-SalSer914']
# row: [33, 'pAC-SalSer914']
# row: [33, 'pAC-SalSer914']
# row: [34, 'pBAC874t']
# row: [35, 'pBAC872s']
# row: [35, 'pBAC872s']
# row: [35, 'pBAC872s']
# row: [36, 'pBACr-Mgr901']
# row: [37, 'pBACr-AraT7940']
# row: [37, 'pBACr-AraT7940']
# row: [37, 'pBACr-AraT7940']
# row: [38, 'pBACr-Mgr940']
# row: [39, 'pBACr-Mgr951']
# row: [39, 'pBACr-Mgr951']
# row: [39, 'pBACr-Mgr951']
# row: [40, 'pBR939B']
# row: [43, 'pINV-107-mutx']
# row: [44, 'pLD']
# row: [44, 'pLD']
# row: [44, 'pLD']
# row: [46, 'pHD-gfp']
# row: [46, 'pHD-gfp']
# row: [46, 'pHD-gfp']
# row: [46, 'pHD-gfp']
# row: [47, 'pHD-rfp']
# row: [47, 'pHD-rfp']
# row: [47, 'pHD-rfp']
# row: [47, 'pHD-rfp']
# row: [48, 'pCFP']
# row: [48, 'pCFP']
# row: [48, 'pCFP']
# row: [49, 'pRFP']
# row: [49, 'pRFP']
# row: [49, 'pRFP']
# row: [50, 'pJS167']
# row: [50, 'pJS167']
# row: [50, 'pJS167']
# row: [51, 'pJS169']
# row: [51, 'pJS169']
# row: [51, 'pJS169']
# row: [52, 'pJS169']
# row: [53, 'pJT108']
# row: [54, 'pJT105']
# row: [54, 'pJT105']
# row: [54, 'pJT105']
# row: [55, 'pJT106']
# row: [54, 'pJT105']
# row: [55, 'pJT106']
# row: [55, 'pJT106']
# row: [55, 'pJT106']
# row: [56, 'pEDL3']
# row: [56, 'pEDL3']
# row: [56, 'pEDL3']
# row: [56, 'pEDL3']
# row: [56, 'pEDL3']
# row: [57, 'pLuxRI2']
# row: [57, 'pLuxRI2']
# row: [57, 'pLuxRI2']
# row: [58, 'pluxCcdB3']
# row: [59, 'predator1-MG1655']
# row: [65, 'pRV2-SOS']
# row: [67, 'pZE21-MCS1-gfp']
# row: [68, 'PLuxI-Tet-8']
# row: [69, 'pLTSUB-202-RBSH']
# row: [69, 'pLTSUB-202-RBSH']
# row: [69, 'pLTSUB-202-RBSH']
# row: [71, 'pCRT1']
# row: [71, 'pCRT1']
# row: [71, 'pCRT1']
# row: [72, 'pCRT2']
# row: [72, 'pCRT2']
# row: [72, 'pCRT2']
# row: [72, 'pCRT2']
# row: [73, 'pCRT3']
# row: [73, ' pCRT3']
# row: [73, ' pCRT3']
# row: [73, ' pCRT3']
# row: [73, ' pCRT3']
# row: [74, 'pTara:500']
# row: [74, 'pTara:500']
# row: [74, 'pTara:500']
# row: [75, 'pTSara-N']
# row: [75, 'pTSara-N']
# row: [75, 'pTSara-N']
# row: [76, 'pTSara-C']
# row: [76, 'pTSara-C']
# row: [76, 'pTSara-C']
# row: [77, 'pTSlb']
# row: [77, 'pTSlb']
# row: [77, 'pTSlb']
# row: [78, 'pET:NNNN:GFP']
# row: [78, 'pET:NNNN:GFP']
# row: [78, 'pET:NNNN:GFP']
# row: [78, 'pET:NNNN:GFP']
# row: [79, 'pBAD-cI-pOR1-gfp']
# row: [79, 'pBAD-cI-pOR1-gfp']
# row: [79, 'pBAD-cI-pOR1-gfp']
# row: [79, 'pBAD-cI-pOR1-gfp']
# row: [80, 'pBAD-cI-pOR1-gfp']
# row: [80, 'pBAD-cI-pOR1-gfp']
# row: [80, 'pBAD-cI-pOR1-gfp']
# row: [80, 'pBAD-cI-pOR1-gfp']
# row: [81, 'pBAD-cI-pOR1-gfp']
# row: [81, 'pBAD-cI-pOR1-gfp']
# row: [81, 'pBAD-cI-pOR1-gfp']
# row: [81, 'pBAD-cI-pOR1-gfp']
# row: [82, 'pTACsym-yfp']
# row: [82, 'pTACsym-yfp']
# row: [82, 'pTACsym-yfp']
# row: [88, 'pBAD-rfp']
# row: [88, 'pBAD-rfp']
# row: [88, 'pBAD-rfp']
# row: [89, 'pTac-rfp']
# row: [89, 'pTac-rfp']
# row: [89, 'pTac-rfp']
# row: [90, 'pLux-rfp']
# row: [90, 'pLux-rfp']
# row: [90, 'pLux-rfp']
# row: [91, 'pTet-rfp']
# row: [91, 'pTet-rfp']
# row: [91, 'pTet-rfp']
# row: [92, 'pTET-invF']
# row: [92, 'pTET-invF']
# row: [92, 'pTET-invF']
# row: [93, 'pBAD-sicA']
# row: [93, 'pBAD-sicA']
# row: [93, 'pBAD-sicA']
# row: [94, 'psicA-rfp']
# row: [95, 'pTet-mxiE']
# row: [95, 'pTet-mxiE']
# row: [95, 'pTet-mxiE']
# row: [96, 'pBAD-ipgC']
# row: [96, 'pBAD-ipgC']
# row: [96, 'pBAD-ipgC']
# row: [97, 'pipaH-rfp']
# row: [98, 'pTet-exsDA']
# row: [98, 'pTet-exsDA']
# row: [98, 'pTet-exsDA']
# row: [99, 'pLux-exsC']
# row: [99, 'pLux-exsC']
# row: [99, 'pLux-exsC']
# row: [100, 'pexsC-rfp']
# row: [101, 'pACPc-invF']
# row: [101, 'pACPc-invF']
# row: [101, 'pACPc-invF']
# row: [101, 'pACPc-invF']
# row: [101, 'pACPc-invF']
# row: [101, 'pACPc-invF']
# row: [102, 'pXCPi-sicA']
# row: [102, 'pXCPi-sicA']
# row: [102, 'pXCPi-sicA']
# row: [102, 'pXCPi-sicA']
# row: [102, 'pXCPi-sicA']
# row: [102, 'pXCPi-sicA']
# row: [103, 'plac/ara-1']
# row: [104, 'pLuxI']

# %%
db_print_table(cur, "Plasmid")
# Out:
# ('P_ID', 'p_name', None)

# %% [markdown]
# ### Populate table Operon

# %%
def db_populate_operon(cursor, sbider_data):
    
    db_delete(cursor, "Operon")
    
    o_id_structure = sbider_data[['O_ID', 'Structure']]

    ###print "o_id_structure:\n\n", o_id_structure

    o_id_structure_lists = o_id_structure.values.T.tolist()

    ###print "o_id_structure_lists:\n", o_id_structure_lists

    o_id_structure_list = [row for row in it.izip(*o_id_structure_lists)]

    ###print "o_id_structure_list:\n", p_id_p_name_list

    inserted_operon_set = set([])
    for row in o_id_structure_list:
        row = format_values(row)
        
        ###print "row:", row
        
        if row[0] not in inserted_operon_set and row[0] != "na":

            ###print "o_id   structure:\t", row[0], " ", row[1]

            db_insert(cursor, 'Operon', ['ope_id', 'name'], row)
            inserted_operon_set.add(row[0])

# %%
db_populate_operon(cur, source_data)

# %%
db_print_table(cur, "Operon")
# Out:
# ('1,1', 'pLuxI_pLacO--->gfp', None)
# ('2,1', 'pBAD--->yfp', None)
# ('2,2', 'pCONST--->araC', None)
# ('3,1', 'pTet--->yfp', None)
# ('3,2', 'pCONST--->tetR', None)
# ('4,1', 'pLasI--->yfp', None)
# ('4,2', 'pCONST--->lasR', None)
# ('5,1', 'pBAD_pTet--->yfp', None)
# ('5,2', 'pCONST--->araC_tetR', None)
# ('6,1', 'pBAD_pLasI--->yfp', None)
# ('6,2', 'pCONST--->araC_lasR', None)
# ('7,1', 'pTet_pLasI--->yfp', None)
# ('7,2', 'pCONST--->lasR_tetR', None)
# ('8,1', 'pBAD_pTet--->cI', None)
# ('8,2', 'pCONST--->araC_tetR', None)
# ('9,1', 'pBAD_pLas--->cI', None)
# ('9,2', 'pCONST--->araC_lasR', None)
# ('10,1', 'pTet_pLas--->cI', None)
# ('10,2', 'pCONST--->lasR_tetR', None)
# ('12,1', 'pLAMBDA--->yfp', None)
# ('13,1', 'pLAMBDA--->LasI', None)
# ('14,1', 'pLAMBDA--->RhlI', None)
# ('15,1', 'pLac--->gfp', None)
# ('16,1', 'pTet--->gfp', None)
# ('17,1', 'pLAMBDA--->gfp', None)
# ('18,1', 'pLac--->gfp', None)
# ('18,2', 'pLAMBDA--->LacI', None)
# ('19,1', 'pLAMBDA--->gfp', None)
# ('19,2', 'pLac--->cI', None)
# ('20,1', 'pTet--->gfp', None)
# ('20,2', 'pLac--->tetR', None)
# ('21,1', 'pLac--->cI_gfp', None)
# ('21,2', 'pLAMBDA--->LacI', None)
# ('22,1', 'pTet--->LacI', None)
# ('22,2', 'pLac--->tetR_gfp', None)
# ('23,1', 'pLac--->gfp', None)
# ('23,2', 'pLacIq--->lacIq', None)
# ('24,1', 'pAraC--->araC', None)
# ('24,2', 'pBAD--->gfp', None)
# ('25,1', 'pTet--->luxR', None)
# ('25,2', 'pLux--->gfp', None)
# ('28,1', 'pTet--->luxR', None)
# ('28,2', 'pLux--->hrpR', None)
# ('29,1', 'pLac--->cI', None)
# ('29,2', 'pLAMBDA--->gfp', None)
# ('29,3', 'pLacIq--->lacIq', None)
# ('31,1', 'phrpL--->cI', None)
# ('31,2', 'pLAMBDA--->gfp', None)
# ('33,1', 'pSal--->supD', None)
# ('33,2', 'pCONST--->nahR', None)
# ('35,1', 'pBAD--->gfp', None)
# ('35,2', 'pCONST--->araC', None)
# ('37,1', 'pBAD--->T7ptag', None)
# ('37,2', 'pCONST--->araC', None)
# ('39,1', 'pT7--->inv', None)
# ('39,2', 'pmgrB--->T7ptag', None)
# ('44,1', 'pLux--->cI', None)
# ('44,2', 'pLAMBDA--->LacI', None)
# ('46,1', 'pLux--->LacI', None)
# ('46,2', 'pLac--->gfp', None)
# ('46,3', 'pCONST--->luxR', None)
# ('47,1', 'pLux--->LacI', None)
# ('47,2', 'pLac--->rfp', None)
# ('47,3', 'pCONST--->luxR', None)
# ('48,1', 'pLac--->ecfp', None)
# ('48,2', 'pCONST--->lacI', None)
# ('49,1', 'pLac--->rfp', None)
# ('49,2', 'pCONST--->lacI', None)
# ('50,1', 'pLac_pBAD--->gfp', None)
# ('51,1', 'pLac_pBAD--->LacI', None)
# ('52,1', 'pTet--->LuxR', None)
# ('54,1', 'pompC--->luxI', None)
# ('54,3', 'pLux_pLAMBDA--->lacZ', None)
# ('55,2', 'pLux_pLAMBDA--->lacZ', None)
# ('55,3', 'pompC--->cI', None)
# ('56,1', 'pLux_pLAMBDA--->lacZ', None)
# ('56,2', 'pompC--->cI_luxI', None)
# ('56,3', 'pTet--->LuxR', None)
# ('57,1', 'pLac_pBAD--->LuxR_luxI', None)
# ('69,1', 'pCONST--->LuxR', None)
# ('69,2', 'pLux--->cI_ecfp', None)
# ('71,1', 'pCONST--->tetR', None)
# ('71,2', 'pTet--->yfp', None)
# ('72,1', 'pCONST--->tetR', None)
# ('72,2', 'pTet--->lacI', None)
# ('72,3', 'pLac--->yfp', None)
# ('73,1', 'pLAMBDA--->yfp', None)
# ('73,2', 'pLac--->cI', None)
# ('73,3', 'pTet--->LacI', None)
# ('73,4', 'pCONST--->tetR', None)
# ('74,1', 'pBAD--->T7', None)
# ('74,2', 'pCONST--->araC', None)
# ('75,1', 'pBAD--->T7-N', None)
# ('75,2', 'pCONST--->araC', None)
# ('76,1', 'pBAD-->T7-C', None)
# ('76,2', 'pCONST--->araC', None)
# ('77,1', 'pLac--->T7-N', None)
# ('77,2', 'pBAD--->T7-C', None)
# ('78,1', 'pT7--->gfp', None)
# ('78,2', 'pCONST--->lacI', None)
# ('79,1', 'pBAD--->cI', None)
# ('79,2', 'pLAMBDA--->gfp', None)
# ('79,3', 'pCONST--->araC', None)
# ('80,1', 'pTAC--->cI', None)
# ('80,2', 'pLAMBDA--->gfp', None)
# ('80,3', 'pCONST--->lacI', None)
# ('81,1', 'pLac--->cI', None)
# ('81,2', 'pLAMBDA--->gfp', None)
# ('81,3', 'pCONST--->lacI', None)
# ('82,1', 'pTAC--->yfp', None)
# ('82,2', 'pCONST--->lacI', None)
# ('88,1', 'pBAD--->rfp', None)
# ('88,2', 'pCONST--->araC', None)
# ('89,1', 'pTAC--->rfp', None)
# ('89,2', 'pCONST--->lacI', None)
# ('90,1', 'pLux--->rfp', None)
# ('90,2', 'pCONST--->luxR', None)
# ('91,1', 'pTet--->rfp', None)
# ('91,2', 'pCONST--->tetR', None)
# ('92,1', 'pTET--->invF', None)
# ('92,2', 'pCONST--->tetR', None)
# ('93,1', 'pBAD--->sicA', None)
# ('93,2', 'pCONST--->araC', None)
# ('94,1', 'psicA--->rfp', None)
# ('95,1', 'pTet--->mxiE', None)
# ('95,2', 'pCONST--->tetR', None)
# ('96,1', 'pBAD--->ipgC', None)
# ('96,2', 'pCONST--->araC', None)
# ('97,1', 'pipaH--->rfp', None)
# ('98,1', 'pTet--->exsDA', None)
# ('98,2', 'pCONST--->tetR', None)
# ('99,1', 'pLux--->exsC', None)
# ('99,2', 'pCONST-->luxR', None)
# ('100,1', 'pexsC--->rfp', None)
# ('101,1', 'pexsC--->invF', None)
# ('101,2', 'pTet--->exsDA', None)
# ('101,3', 'pLux--->exsC', None)
# ('101,4', 'pCONST--->luxR', None)
# ('101,5', 'pCONST--->tetR', None)
# ('102,1', 'pipaH--->sicA', None)
# ('102,2', 'pBAD--->ipgC', None)
# ('102,3', 'pTAC--->mxiE', None)
# ('102,4', 'pCONST--->araC', None)
# ('102,5', 'pCONST--->lacI', None)
# ('103,1', 'pLac/ara-1--->LuxR_luxI', None)
# ('104,1', 'pLuxI--->lacZalpha-ccdB', None)

# %% [markdown]
# ### Populate table PlasmidOperon

# %%
def db_populate_plasmid_operon(cursor, sbider_data):
    
    db_delete(cursor, "PlasmidOperon")

    p_id_o_id_direction = sbider_data[['P_ID', 'O_ID', 'R/L']]

    ###print "p_id_o_id_direction:\n\n", p_id_o_id_direction

    p_id_o_id_direction_lists = p_id_o_id_direction.values.T.tolist()

    ###print "p_id_o_id_direction_lists:\n", p_id_o_id_direction_lists

    p_id_o_id_direction_list = [row for row in it.izip(*p_id_o_id_direction_lists)]

    ###print "p_id_o_id_direction_list:\n", p_id_o_id_direction_list

    inserted_plasmid_operon_set = set([])
    for row in p_id_o_id_direction_list:
        row = format_values(row)
        
        print "row:", row
        
        if row[1].strip() not in inserted_plasmid_operon_set and row[1] != "na":

            ###print "ope_id   pla_id   direction:\t", row[1], " ", row[0], " ", row[2]

            db_insert(cursor, 'PlasmidOperon', ['pla_id', 'ope_id', 'direction'], row)
            inserted_plasmid_operon_set.add(row[1])

# %%
db_populate_plasmid_operon(cur, source_data)
# Out:
# row: [1, 'na', 'R']
# row: [1, '1,1', 'R']
# row: [1, '1,1', 'R']
# row: [2, 'na', 'na']
# row: [2, '2,1', 'R']
# row: [2, '2,2', 'R']
# row: [3, 'na', 'na']
# row: [3, '3,1', 'R']
# row: [3, '3,2', 'R']
# row: [4, 'na', 'na']
# row: [4, '4,1', 'R']
# row: [4, '4,2', 'R']
# row: [5, 'na', 'na']
# row: [5, '5,1', 'R']
# row: [5, '5,1', 'R']
# row: [5, '5,2', 'R']
# row: [6, 'na', 'na']
# row: [6, '6,1', 'R']
# row: [6, '6,1', 'R']
# row: [6, '6,2', 'R']
# row: [7, 'na', 'na']
# row: [7, '7,1', 'R']
# row: [7, '7,1', 'R']
# row: [7, '7,2', 'R']
# row: [8, 'na', 'na']
# row: [8, '8,1', 'R']
# row: [8, '8,1', 'R']
# row: [8, '8,2', 'R']
# row: [9, 'na', 'na']
# row: [9, '9,1', 'R']
# row: [9, '9,1', 'R']
# row: [9, '9,2', 'R']
# row: [10, 'na', 'na']
# row: [10, '10,1', 'R']
# row: [10, '10,1', 'R']
# row: [10, '10,2', 'R']
# row: [12, '12,1', 'R']
# row: [13, '13,1', 'R']
# row: [14, '14,1', 'R']
# row: [15, '15,1', 'R']
# row: [16, '16,1', 'R']
# row: [17, '17,1', 'R']
# row: [18, 'na', 'na']
# row: [18, '18,1', 'R']
# row: [18, '18,2', 'L']
# row: [19, 'na', 'na']
# row: [19, '19,1', 'L']
# row: [19, '19,2', 'R']
# row: [20, 'na', 'na']
# row: [20, '20,1', 'L']
# row: [20, '20,2', 'R']
# row: [21, 'na', 'na']
# row: [21, '21,1', 'R']
# row: [21, '21,2', 'L']
# row: [22, 'na', 'na']
# row: [22, '22,1', 'L']
# row: [22, '22,2', 'R']
# row: [23, 'na', 'na']
# row: [23, '23,1', 'R']
# row: [23, '23,2', 'R']
# row: [24, 'na', 'na']
# row: [24, '24,1', 'L']
# row: [24, '24,2', 'R']
# row: [25, 'na', 'na']
# row: [25, '25,1', 'R']
# row: [25, '25,2', 'R']
# row: [28, 'na', 'na']
# row: [28, '28,1', 'R']
# row: [28, '28,2', 'R']
# row: [29, 'na', 'na']
# row: [29, '29,1', 'R']
# row: [29, '29,2', 'R']
# row: [29, '29,3', 'R']
# row: [30, 'na', 'R']
# row: [31, 'na', 'na']
# row: [31, '31,1', 'R']
# row: [31, '31,2', 'R']
# row: [33, 'na', 'na']
# row: [33, '33,1', 'R']
# row: [33, '33,2', 'L']
# row: [34, 'na', 'R']
# row: [35, 'na', 'na']
# row: [35, '35,1', 'R']
# row: [35, '35,2', 'L']
# row: [36, 'na', 'R']
# row: [37, 'na', 'na']
# row: [37, '37,1', 'R']
# row: [37, '37,2', 'L']
# row: [38, 'na', 'R']
# row: [39, 'na', 'na']
# row: [39, '39,1', 'L']
# row: [39, '39,2', 'R']
# row: [40, 'na', 'R']
# row: [43, 'na', 'R']
# row: [44, 'na', 'na']
# row: [44, '44,1', 'R']
# row: [44, '44,2', 'R']
# row: [46, 'na', 'na']
# row: [46, '46,1', 'L']
# row: [46, '46,2', 'R']
# row: [46, '46,3', 'R']
# row: [47, 'na', 'na']
# row: [47, '47,1', 'L']
# row: [47, '47,2', 'R']
# row: [47, '47,3', 'R']
# row: [48, 'na', 'na']
# row: [48, '48,1', 'R']
# row: [48, '48,2', 'L']
# row: [49, 'na', 'na']
# row: [49, '49,1', 'R']
# row: [49, '49,2', 'L']
# row: [50, 'na', 'na']
# row: [50, '50,1', 'R']
# row: [50, '50,1', 'R']
# row: [51, 'na', 'na']
# row: [51, '51,1', 'R']
# row: [51, '51,1', 'R']
# row: [52, '52,1', 'R']
# row: [53, 'na', 'R']
# row: [54, 'na', 'na']
# row: [54, '54,1', 'R']
# row: [54, '54,3', 'R']
# row: [55, 'na', 'na']
# row: [54, '54,3', 'R']
# row: [55, '55,2', 'R']
# row: [55, '55,2', 'R']
# row: [55, '55,3', 'R']
# row: [56, 'na', 'na']
# row: [56, '56,1', 'R']
# row: [56, '56,1', 'R']
# row: [56, '56,2', 'R']
# row: [56, '56,3', 'R']
# row: [57, 'na', 'na']
# row: [57, '57,1', 'R']
# row: [57, '57,1', 'R']
# row: [58, 'na', 'na']
# row: [59, 'na', 'na']
# row: [65, 'na', 'na']
# row: [67, 'na', 'na']
# row: [68, 'na', 'R']
# row: [69, 'na', 'na']
# row: [69, '69,1', 'L']
# row: [69, '69,2', 'R']
# row: [71, 'na', 'na']
# row: [71, '71,1', 'R']
# row: [71, '71,2', 'R']
# row: [72, 'na', 'na']
# row: [72, '72,1', 'R']
# row: [72, '72,2', 'R']
# row: [72, '72,3', 'R']
# row: [73, 'na', 'na']
# row: [73, '73,1', 'R']
# row: [73, '73,2', 'R']
# row: [73, '73,3', 'R']
# row: [73, '73,4', 'R']
# row: [74, 'na', 'na']
# row: [74, '74,1', 'R']
# row: [74, '74,2', 'L']
# row: [75, 'na', 'na']
# row: [75, '75,1', 'R']
# row: [75, '75,2', 'L']
# row: [76, 'na', 'na']
# row: [76, '76,1', 'R']
# row: [76, '76,2', 'L']
# row: [77, 'na', 'na']
# row: [77, '77,1', 'L']
# row: [77, '77,2', 'R']
# row: [78, 'na', 'na']
# row: [78, '78,1', 'L']
# row: [78, '78,1', 'L']
# row: [78, '78,2', 'R']
# row: [79, 'na', 'na']
# row: [79, '79,1', 'R']
# row: [79, '79,2', 'R']
# row: [79, '79,3', 'R']
# row: [80, 'na', 'na']
# row: [80, '80,1', 'R']
# row: [80, '80,2', 'R']
# row: [80, '80,3', 'R']
# row: [81, 'na', 'na']
# row: [81, '81,1', 'R']
# row: [81, '81,2', 'R']
# row: [81, '81,3', 'R']
# row: [82, 'na', 'na']
# row: [82, '82,1', 'R']
# row: [82, '82,2', 'L']
# row: [88, 'na', 'na']
# row: [88, '88,1', 'R']
# row: [88, '88,2', 'L']
# row: [89, 'na', 'na']
# row: [89, '89,1', 'R']
# row: [89, '89,2', 'L']
# row: [90, 'na', 'na']
# row: [90, '90,1', 'R']
# row: [90, '90,2', 'L']
# row: [91, 'na', 'na']
# row: [91, '91,1', 'R']
# row: [91, '91,2', 'L']
# row: [92, 'na', 'na']
# row: [92, '92,1', 'R']
# row: [92, '92,2', 'L']
# row: [93, 'na', 'na']
# row: [93, '93,1', 'R']
# row: [93, '93,2', 'L']
# row: [94, '94,1', 'R']
# row: [95, 'na', 'na']
# row: [95, '95,1', 'R']
# row: [95, '95,2', 'L']
# row: [96, 'na', 'na']
# row: [96, '96,1', 'R']
# row: [96, '96,2', 'L']
# row: [97, '97,1', 'R']
# row: [98, 'na', 'na']
# row: [98, '98,1', 'R']
# row: [98, '98,2', 'L']
# row: [99, 'na', 'na']
# row: [99, '99,1', 'R']
# row: [99, '99,2', 'L']
# row: [100, '100,1', 'R']
# row: [101, 'na', 'na']
# row: [101, '101,1', 'L']
# row: [101, '101,2', 'R']
# row: [101, '101,3', 'L']
# row: [101, '101,4', 'R']
# row: [101, '101,5', 'L']
# row: [102, 'na', 'na']
# row: [102, '102,1', 'R']
# row: [102, '102,2', 'L']
# row: [102, '102,3', 'R']
# row: [102, '102,4', 'R']
# row: [102, '102,5', 'L']
# row: [103, '103,1', 'R']
# row: [104, '104,1', 'R']

# %%
db_print_table(cur, "PlasmidOperon")
# Out:
# ('1,1', '1', 'R')
# ('2,1', '2', 'R')
# ('2,2', '2', 'R')
# ('3,1', '3', 'R')
# ('3,2', '3', 'R')
# ('4,1', '4', 'R')
# ('4,2', '4', 'R')
# ('5,1', '5', 'R')
# ('5,2', '5', 'R')
# ('6,1', '6', 'R')
# ('6,2', '6', 'R')
# ('7,1', '7', 'R')
# ('7,2', '7', 'R')
# ('8,1', '8', 'R')
# ('8,2', '8', 'R')
# ('9,1', '9', 'R')
# ('9,2', '9', 'R')
# ('10,1', '10', 'R')
# ('10,2', '10', 'R')
# ('12,1', '12', 'R')
# ('13,1', '13', 'R')
# ('14,1', '14', 'R')
# ('15,1', '15', 'R')
# ('16,1', '16', 'R')
# ('17,1', '17', 'R')
# ('18,1', '18', 'R')
# ('18,2', '18', 'L')
# ('19,1', '19', 'L')
# ('19,2', '19', 'R')
# ('20,1', '20', 'L')
# ('20,2', '20', 'R')
# ('21,1', '21', 'R')
# ('21,2', '21', 'L')
# ('22,1', '22', 'L')
# ('22,2', '22', 'R')
# ('23,1', '23', 'R')
# ('23,2', '23', 'R')
# ('24,1', '24', 'L')
# ('24,2', '24', 'R')
# ('25,1', '25', 'R')
# ('25,2', '25', 'R')
# ('28,1', '28', 'R')
# ('28,2', '28', 'R')
# ('29,1', '29', 'R')
# ('29,2', '29', 'R')
# ('29,3', '29', 'R')
# ('31,1', '31', 'R')
# ('31,2', '31', 'R')
# ('33,1', '33', 'R')
# ('33,2', '33', 'L')
# ('35,1', '35', 'R')
# ('35,2', '35', 'L')
# ('37,1', '37', 'R')
# ('37,2', '37', 'L')
# ('39,1', '39', 'L')
# ('39,2', '39', 'R')
# ('44,1', '44', 'R')
# ('44,2', '44', 'R')
# ('46,1', '46', 'L')
# ('46,2', '46', 'R')
# ('46,3', '46', 'R')
# ('47,1', '47', 'L')
# ('47,2', '47', 'R')
# ('47,3', '47', 'R')
# ('48,1', '48', 'R')
# ('48,2', '48', 'L')
# ('49,1', '49', 'R')
# ('49,2', '49', 'L')
# ('50,1', '50', 'R')
# ('51,1', '51', 'R')
# ('52,1', '52', 'R')
# ('54,1', '54', 'R')
# ('54,3', '54', 'R')
# ('55,2', '55', 'R')
# ('55,3', '55', 'R')
# ('56,1', '56', 'R')
# ('56,2', '56', 'R')
# ('56,3', '56', 'R')
# ('57,1', '57', 'R')
# ('69,1', '69', 'L')
# ('69,2', '69', 'R')
# ('71,1', '71', 'R')
# ('71,2', '71', 'R')
# ('72,1', '72', 'R')
# ('72,2', '72', 'R')
# ('72,3', '72', 'R')
# ('73,1', '73', 'R')
# ('73,2', '73', 'R')
# ('73,3', '73', 'R')
# ('73,4', '73', 'R')
# ('74,1', '74', 'R')
# ('74,2', '74', 'L')
# ('75,1', '75', 'R')
# ('75,2', '75', 'L')
# ('76,1', '76', 'R')
# ('76,2', '76', 'L')
# ('77,1', '77', 'L')
# ('77,2', '77', 'R')
# ('78,1', '78', 'L')
# ('78,2', '78', 'R')
# ('79,1', '79', 'R')
# ('79,2', '79', 'R')
# ('79,3', '79', 'R')
# ('80,1', '80', 'R')
# ('80,2', '80', 'R')
# ('80,3', '80', 'R')
# ('81,1', '81', 'R')
# ('81,2', '81', 'R')
# ('81,3', '81', 'R')
# ('82,1', '82', 'R')
# ('82,2', '82', 'L')
# ('88,1', '88', 'R')
# ('88,2', '88', 'L')
# ('89,1', '89', 'R')
# ('89,2', '89', 'L')
# ('90,1', '90', 'R')
# ('90,2', '90', 'L')
# ('91,1', '91', 'R')
# ('91,2', '91', 'L')
# ('92,1', '92', 'R')
# ('92,2', '92', 'L')
# ('93,1', '93', 'R')
# ('93,2', '93', 'L')
# ('94,1', '94', 'R')
# ('95,1', '95', 'R')
# ('95,2', '95', 'L')
# ('96,1', '96', 'R')
# ('96,2', '96', 'L')
# ('97,1', '97', 'R')
# ('98,1', '98', 'R')
# ('98,2', '98', 'L')
# ('99,1', '99', 'R')
# ('99,2', '99', 'L')
# ('100,1', '100', 'R')
# ('101,1', '101', 'L')
# ('101,2', '101', 'R')
# ('101,3', '101', 'L')
# ('101,4', '101', 'R')
# ('101,5', '101', 'L')
# ('102,1', '102', 'R')
# ('102,2', '102', 'L')
# ('102,3', '102', 'R')
# ('102,4', '102', 'R')
# ('102,5', '102', 'L')
# ('103,1', '103', 'R')
# ('104,1', '104', 'R')

# %% [markdown]
# ### Populate tables OperonInputTransition, InputTransitionSpecies, and InputTransitoin

# %%
def db_populate_operon_input_transition_species(cursor, sbider_data):
    
    db_delete(cursor, "OperonInputTransition")
    db_delete(cursor, "InputTransitionSpecies")
    db_delete(cursor, "InputTransition")

    o_id_domain = sbider_data[['O_ID', 'Domain']]

    ###print "o_id_domain:\n\n", o_id_domain

    o_id_domain_lists = o_id_domain.values.T.tolist()

    ###print "o_id_domain_lists:\n", o_id_domain_lists

    o_id_domain_list = [row for row in it.izip(*o_id_domain_lists)]

    ###print "o_id_domain_list:\n", o_id_domain_list

    in_id_count = 1
    it_id_count = 1
    for row in o_id_domain_list:
        row = format_values(row)

        ###print "row", row

        if row[0] != "na":

            ###print "o_id   domain:\t", row[0], " ", row[1]

            species_list = row[1].split(',')

            ###print "split_species:", species_list

            logic_counter = 0
            for species in species_list:

                ###print "Going into the species loop"

                stripped_lower_species = species.strip().lower()

                ###print "stripped_species:", stripped_species

                species_id = db_get_species_id_from_name(cursor,"'%s'" % stripped_lower_species)
                db_insert(cursor,'InputTransitionSpecies', 
                          ['in_id', 'it_id', 'spe_id'],
                          [in_id_count, it_id_count, species_id])

                #print "in_id   it_id   spe_id:\t", in_id_count, " ", it_id_count, " ", spe_id

                in_id_count += 1
                logic_counter = logic_counter + 1
                
                ###print "logic counter:", logic_counter
                
            db_insert(cursor, 'OperonInputTransition', ['it_id','ope_id'], [it_id_count, row[0]])                    
            
            if logic_counter > 1:
                logic = "AND"
            else:
                logic = "OR"
                
            db_insert(cursor, 'InputTransition', ['it_id','logic'], [it_id_count, logic])
            logic_counter = 1
            it_id_count = it_id_count + 1

# %%
db_populate_operon_input_transition_species(cur, source_data)

# %%
db_print_table(cur, "OperonInputTransition")
# Out:
# ('1', '1,1')
# ('2', '1,1')
# ('3', '2,1')
# ('4', '2,2')
# ('5', '3,1')
# ('6', '3,2')
# ('7', '4,1')
# ('8', '4,2')
# ('9', '5,1')
# ('10', '5,1')
# ('11', '5,2')
# ('12', '6,1')
# ('13', '6,1')
# ('14', '6,2')
# ('15', '7,1')
# ('16', '7,1')
# ('17', '7,2')
# ('18', '8,1')
# ('19', '8,1')
# ('20', '8,2')
# ('21', '9,1')
# ('22', '9,1')
# ('23', '9,2')
# ('24', '10,1')
# ('25', '10,1')
# ('26', '10,2')
# ('27', '12,1')
# ('28', '13,1')
# ('29', '14,1')
# ('30', '15,1')
# ('31', '16,1')
# ('32', '17,1')
# ('33', '18,1')
# ('34', '18,2')
# ('35', '19,1')
# ('36', '19,2')
# ('37', '20,1')
# ('38', '20,2')
# ('39', '21,1')
# ('40', '21,2')
# ('41', '22,1')
# ('42', '22,2')
# ('43', '23,1')
# ('44', '23,2')
# ('45', '24,1')
# ('46', '24,2')
# ('47', '25,1')
# ('48', '25,2')
# ('49', '28,1')
# ('50', '28,2')
# ('51', '29,1')
# ('52', '29,2')
# ('53', '29,3')
# ('54', '31,1')
# ('55', '31,2')
# ('56', '33,1')
# ('57', '33,2')
# ('58', '35,1')
# ('59', '35,2')
# ('60', '37,1')
# ('61', '37,2')
# ('62', '39,1')
# ('63', '39,2')
# ('64', '44,1')
# ('65', '44,2')
# ('66', '46,1')
# ('67', '46,2')
# ('68', '46,3')
# ('69', '47,1')
# ('70', '47,2')
# ('71', '47,3')
# ('72', '48,1')
# ('73', '48,2')
# ('74', '49,1')
# ('75', '49,2')
# ('76', '50,1')
# ('77', '50,1')
# ('78', '51,1')
# ('79', '51,1')
# ('80', '52,1')
# ('81', '54,1')
# ('82', '54,3')
# ('83', '54,3')
# ('84', '55,2')
# ('85', '55,2')
# ('86', '55,3')
# ('87', '56,1')
# ('88', '56,1')
# ('89', '56,2')
# ('90', '56,3')
# ('91', '57,1')
# ('92', '57,1')
# ('93', '69,1')
# ('94', '69,2')
# ('95', '71,1')
# ('96', '71,2')
# ('97', '72,1')
# ('98', '72,2')
# ('99', '72,3')
# ('100', '73,1')
# ('101', '73,2')
# ('102', '73,3')
# ('103', '73,4')
# ('104', '74,1')
# ('105', '74,2')
# ('106', '75,1')
# ('107', '75,2')
# ('108', '76,1')
# ('109', '76,2')
# ('110', '77,1')
# ('111', '77,2')
# ('112', '78,1')
# ('113', '78,1')
# ('114', '78,2')
# ('115', '79,1')
# ('116', '79,2')
# ('117', '79,3')
# ('118', '80,1')
# ('119', '80,2')
# ('120', '80,3')
# ('121', '81,1')
# ('122', '81,2')
# ('123', '81,3')
# ('124', '82,1')
# ('125', '82,2')
# ('126', '88,1')
# ('127', '88,2')
# ('128', '89,1')
# ('129', '89,2')
# ('130', '90,1')
# ('131', '90,2')
# ('132', '91,1')
# ('133', '91,2')
# ('134', '92,1')
# ('135', '92,2')
# ('136', '93,1')
# ('137', '93,2')
# ('138', '94,1')
# ('139', '95,1')
# ('140', '95,2')
# ('141', '96,1')
# ('142', '96,2')
# ('143', '97,1')
# ('144', '98,1')
# ('145', '98,2')
# ('146', '99,1')
# ('147', '99,2')
# ('148', '100,1')
# ('149', '101,1')
# ('150', '101,2')
# ('151', '101,3')
# ('152', '101,4')
# ('153', '101,5')
# ('154', '102,1')
# ('155', '102,2')
# ('156', '102,3')
# ('157', '102,4')
# ('158', '102,5')
# ('159', '103,1')
# ('160', '104,1')

# %%
db_print_table(cur, "InputTransitionSpecies")
# Out:
# ('1', '1', '9', None)
# ('2', '1', '53', None)
# ('3', '2', '26', None)
# ('4', '2', '27', None)
# ('5', '3', '2', None)
# ('6', '3', '14', None)
# ('7', '4', '1', None)
# ('8', '5', '8', None)
# ('9', '5', '56', None)
# ('104', 'AND')
# ('105', 'OR')
# ('106', 'AND')
# ('107', 'OR')
# ('108', 'AND')
# ('109', 'OR')
# ('110', 'AND')
# ('111', 'AND')
# ('112', 'OR')
# ('113', 'AND')
# ('114', 'OR')
# ('115', 'AND')
# ('116', 'OR')
# ('117', 'OR')
# ('118', 'AND')
# ('119', 'OR')
# ('120', 'OR')
# ('121', 'AND')
# ('122', 'OR')
# ('123', 'OR')
# ('124', 'AND')
# ('125', 'OR')
# ('126', 'AND')
# ('127', 'OR')
# ('128', 'AND')
# ('129', 'OR')
# ('130', 'AND')
# ('131', 'OR')
# ('132', 'AND')
# ('133', 'OR')
# ('134', 'AND')
# ('135', 'OR')
# ('136', 'AND')
# ('137', 'OR')
# ('138', 'AND')
# ('139', 'AND')
# ('140', 'OR')
# ('141', 'AND')
# ('142', 'OR')
# ('143', 'AND')
# ('144', 'AND')
# ('145', 'OR')
# ('146', 'AND')
# ('147', 'OR')
# ('148', 'AND')
# ('149', 'AND')
# ('150', 'AND')
# ('151', 'AND')
# ('152', 'OR')
# ('153', 'OR')
# ('154', 'AND')
# ('155', 'AND')
# ('156', 'AND')
# ('157', 'OR')
# ('158', 'OR')
# ('159', 'AND')
# ('160', 'AND')

# %% [markdown]
# ### Populate tables OperonOutputTransition, OutputTransitionSpecies, and OutputTransition

# %%
def db_populate_operon_output_transition_species(cursor, sbider_data):
    
    db_delete(cursor, "OperonOutputTransition")
    db_delete(cursor, "OutputTransitionSpecies")
    db_delete(cursor, "OutputTransition")
    
    o_id_domain = sbider_data[['O_ID', 'Domain']]

    ###print "o_id_domain:\n\n", o_id_domain

    o_id_domain_lists = o_id_domain.values.T.tolist()

    ###print "o_id_domain_lists:\n", o_id_domain_lists

    o_id_domain_list = [row for row in it.izip(*o_id_domain_lists)]

    ###print "o_id_domain_list:\n", o_id_domain_list

    out_id_count = 1
    ot_id_count = 1
    for row in o_id_domain_list:
        row = format_values(row)

        ###print "row", row

        if row[0] != "na":

            ###print "o_id   domain:\t", row[0], " ", row[1]

            species_list = row[1].split(',')

            ###print "split_species:", species_list
            
            logic_counter = 0
            for species in species_list:
                stripped_lower_species = species.strip().lower()

                ###print "stripped_lower_species:", stripped_lower_species

                species_id = db_get_species_id_from_name(cursor,"'%s'" % stripped_lower_species)
                db_insert(cursor,'OutputTransitionSpecies', 
                          ['out_id', 'ot_id', 'spe_id'],
                          [out_id_count, ot_id_count, species_id])

                #print "in_id   it_id   spe_id:\t", in_id_count, " ", it_id_count, " ", spe_id

                out_id_count += 1
                logic_counter = logic_counter + 1
                
                ###print "logic counter:", logic_counter

            db_insert(cursor, 'OperonOutputTransition', ['ot_id','ope_id'], [ot_id_count, row[0]])                                
            
            if logic_counter > 1:
                logic = "AND"
            else:
                logic = "OR"
            
            db_insert(cursor, 'OutputTransition', ['ot_id','logic'], [ot_id_count, logic])
            logic_counter = 1
            ot_id_count = ot_id_count + 1

# %%
db_populate_operon_output_transition_species(cur, source_data)

# %%
db_print_table(cur, "OperonOutputTransition")
# Out:
# ('1', '1,1')
# ('2', '1,1')
# ('3', '2,1')
# ('4', '2,2')
# ('5', '3,1')
# ('6', '3,2')
# ('7', '4,1')
# ('8', '4,2')
# ('9', '5,1')
# ('10', '5,1')
# ('11', '5,2')
# ('12', '6,1')
# ('13', '6,1')
# ('14', '6,2')
# ('15', '7,1')
# ('16', '7,1')
# ('17', '7,2')
# ('18', '8,1')
# ('19', '8,1')
# ('20', '8,2')
# ('21', '9,1')
# ('22', '9,1')
# ('23', '9,2')
# ('24', '10,1')
# ('25', '10,1')
# ('26', '10,2')
# ('27', '12,1')
# ('28', '13,1')
# ('29', '14,1')
# ('30', '15,1')
# ('31', '16,1')
# ('32', '17,1')
# ('33', '18,1')
# ('34', '18,2')
# ('35', '19,1')
# ('36', '19,2')
# ('37', '20,1')
# ('38', '20,2')
# ('39', '21,1')
# ('40', '21,2')
# ('41', '22,1')
# ('42', '22,2')
# ('43', '23,1')
# ('44', '23,2')
# ('45', '24,1')
# ('46', '24,2')
# ('47', '25,1')
# ('48', '25,2')
# ('49', '28,1')
# ('50', '28,2')
# ('51', '29,1')
# ('52', '29,2')
# ('53', '29,3')
# ('54', '31,1')
# ('55', '31,2')
# ('56', '33,1')
# ('57', '33,2')
# ('58', '35,1')
# ('59', '35,2')
# ('60', '37,1')
# ('61', '37,2')
# ('62', '39,1')
# ('63', '39,2')
# ('64', '44,1')
# ('65', '44,2')
# ('66', '46,1')
# ('67', '46,2')
# ('68', '46,3')
# ('69', '47,1')
# ('70', '47,2')
# ('71', '47,3')
# ('72', '48,1')
# ('73', '48,2')
# ('74', '49,1')
# ('75', '49,2')
# ('76', '50,1')
# ('77', '50,1')
# ('78', '51,1')
# ('79', '51,1')
# ('80', '52,1')
# ('81', '54,1')
# ('82', '54,3')
# ('83', '54,3')
# ('84', '55,2')
# ('85', '55,2')
# ('86', '55,3')
# ('87', '56,1')
# ('88', '56,1')
# ('89', '56,2')
# ('90', '56,3')
# ('91', '57,1')
# ('92', '57,1')
# ('93', '69,1')
# ('94', '69,2')
# ('95', '71,1')
# ('96', '71,2')
# ('97', '72,1')
# ('98', '72,2')
# ('99', '72,3')
# ('100', '73,1')
# ('101', '73,2')
# ('102', '73,3')
# ('103', '73,4')
# ('104', '74,1')
# ('105', '74,2')
# ('106', '75,1')
# ('107', '75,2')
# ('108', '76,1')
# ('109', '76,2')
# ('110', '77,1')
# ('111', '77,2')
# ('112', '78,1')
# ('113', '78,1')
# ('114', '78,2')
# ('115', '79,1')
# ('116', '79,2')
# ('117', '79,3')
# ('118', '80,1')
# ('119', '80,2')
# ('120', '80,3')
# ('121', '81,1')
# ('122', '81,2')
# ('123', '81,3')
# ('124', '82,1')
# ('125', '82,2')
# ('126', '88,1')
# ('127', '88,2')
# ('128', '89,1')
# ('129', '89,2')
# ('130', '90,1')
# ('131', '90,2')
# ('132', '91,1')
# ('133', '91,2')
# ('134', '92,1')
# ('135', '92,2')
# ('136', '93,1')
# ('137', '93,2')
# ('138', '94,1')
# ('139', '95,1')
# ('115', 'AND')
# ('116', 'OR')
# ('117', 'OR')
# ('118', 'AND')
# ('119', 'OR')
# ('120', 'OR')
# ('121', 'AND')
# ('122', 'OR')
# ('123', 'OR')
# ('124', 'AND')
# ('125', 'OR')
# ('126', 'AND')
# ('127', 'OR')
# ('128', 'AND')
# ('129', 'OR')
# ('130', 'AND')
# ('131', 'OR')
# ('132', 'AND')
# ('133', 'OR')
# ('134', 'AND')
# ('135', 'OR')
# ('136', 'AND')
# ('137', 'OR')
# ('138', 'AND')
# ('139', 'AND')
# ('140', 'OR')
# ('141', 'AND')
# ('142', 'OR')
# ('143', 'AND')
# ('144', 'AND')
# ('145', 'OR')
# ('146', 'AND')
# ('147', 'OR')
# ('148', 'AND')
# ('149', 'AND')
# ('150', 'AND')
# ('151', 'AND')
# ('152', 'OR')
# ('153', 'OR')
# ('154', 'AND')
# ('155', 'AND')
# ('156', 'AND')
# ('157', 'OR')
# ('158', 'OR')
# ('159', 'AND')
# ('160', 'AND')

# %%
def make_ope_id_spe_id_dicts(sql):
    input_operon_species_dictionary = {}

    merged_ope_it_spe = sql.execute('''SELECT OperonInputTransition.ope_id, 
                                 OperonInputTransition.it_id,
                                 InputTransitionSpecies.spe_id 
                          FROM   OperonInputTransition,
                                 InputTransitionSpecies 
                          WHERE  OperonInputTransition.it_id = InputTransitionSpecies.it_id''')

    ###print "merged_ope_it_spe:",merged_ope_it_spe
    ###print "merged_ope_it_spe.fetchall():",merged_ope_it_spe.fetchall()
    ###print "merged_ope_it_spe.fetchone():",merged_ope_it_spe.fetchone()

    previous_operon, previous_input_transition, previous_species = merged_ope_it_spe.fetchone()

    ###print 'previous_operon, previous_input_transition, previous_species:\t',previous_operon,"",previous_input_transition,"",previous_species

    input_transition_list_idx = 0

    ###print 'input_transition_list_idx', input_transition_list_idx

    input_operon_species_dictionary[previous_operon] = [[]]

    input_operon_species_dictionary[previous_operon][input_transition_list_idx].append(previous_species.strip())

    ###print "input_operon_species_dictionary:",input_operon_species_dictionary

    for operon, input_transition, species in merged_ope_it_spe.fetchall():
        
        print "\toperon, input_transition, species operon:\t",operon, "", input_transition,"", species

        if operon == previous_operon:

            if input_transition == previous_input_transition:

                input_operon_species_dictionary[operon][input_transition_list_idx].append(species.strip())

                ###print "\n\n\tinput_operon_species_dictionary:",input_operon_species_dictionary

            elif input_transition != previous_input_transition:
                input_transition_list_idx = input_transition_list_idx + 1

                input_operon_species_dictionary[operon].append([])
                input_operon_species_dictionary[operon][input_transition_list_idx].append(species.strip())

                previous_input_transition = input_transition

        else:
            input_transition_list_idx = 0
            input_operon_species_dictionary[operon] = [[]]
            input_operon_species_dictionary[operon][input_transition_list_idx].append(species.strip())

            previous_operon = operon
            previous_input_transition = input_transition


    output_operon_species_dictionary = {}

    merged_ope_ot_spe = sql.execute('''SELECT OperonOutputTransition.ope_id, 
                             OperonOutputTransition.ot_id,
                             OutputTransitionSpecies.spe_id 
                      FROM   OperonOutputTransition,
                             OutputTransitionSpecies 
                      WHERE  OperonOutputTransition.ot_id = OutputTransitionSpecies.ot_id''')

    ###print "merged_ope_ot_spe:",merged_ope_ot_spe
    ###print "merged_ope_ot_spe.fetchall():",merged_ope_ot_spe.fetchall()
    ###print "merged_ope_ot_spe.fetchone():",merged_ope_ot_spe.fetchone()
    previous_operon, previous_output_transition, previous_species = merged_ope_ot_spe.fetchone()

    ###print 'previous_operon, previous_output_transition, previous_species:\t',previous_operon,"",previous_output_transition,"",previous_species

    output_transition_list_idx = 0

    ###print 'output_transition_list_idx', output_transition_list_idx

    output_operon_species_dictionary[previous_operon] = [[]]

    output_operon_species_dictionary[previous_operon][output_transition_list_idx].append(previous_species.strip())

    ###print "output_operon_species_dictionary:",output_operon_species_dictionary

    for operon, output_transition, species in merged_ope_ot_spe.fetchall():
        
        ###print "\toperon, output_transition, species operon:\t",operon, "", output_transition,"", species

        if operon == previous_operon:

            if output_transition == previous_output_transition:

                output_operon_species_dictionary[operon][output_transition_list_idx].append(species.strip())

                ###print "\n\n\toutput_operon_species_dictionary:",output_operon_species_dictionary

            elif output_transition != previous_output_transition:
                output_transition_list_idx = output_transition_list_idx + 1

                output_operon_species_dictionary[operon].append([])
                output_operon_species_dictionary[operon][output_transition_list_idx].append(species.strip())

                previous_output_transition = output_transition

        else:
            output_transition_list_idx = 0
            output_operon_species_dictionary[operon] = [[]]
            output_operon_species_dictionary[operon][output_transition_list_idx].append(species.strip())

            previous_operon = operon
            previous_output_transition = output_transition   
        
    return input_operon_species_dictionary, output_operon_species_dictionary

# %%
print make_ope_id_spe_id_dicts(cur)
# Out:
# 	operon, input_transition, species operon:	1,1  1  9
# 	operon, input_transition, species operon:	1,1  2  26
# 	operon, input_transition, species operon:	1,1  2  27
# 	operon, input_transition, species operon:	2,1  3  14
# 	operon, input_transition, species operon:	2,1  3  2
# 	operon, input_transition, species operon:	2,2  4  1
# 	operon, input_transition, species operon:	3,1  5  56
# 	operon, input_transition, species operon:	3,1  5  8
# 	operon, input_transition, species operon:	3,2  6  1
# 	operon, input_transition, species operon:	4,1  7  3
# 	operon, input_transition, species operon:	4,1  7  81
# 	operon, input_transition, species operon:	4,2  8  1
# 	operon, input_transition, species operon:	5,1  9  14
# 	operon, input_transition, species operon:	5,1  9  2
# 	operon, input_transition, species operon:	5,1  10  56
# 	operon, input_transition, species operon:	5,1  10  8
# 	operon, input_transition, species operon:	5,2  11  1
# 	operon, input_transition, species operon:	6,1  12  14
# 	operon, input_transition, species operon:	6,1  12  2
# 	operon, input_transition, species operon:	6,1  13  3
# 	operon, input_transition, species operon:	6,1  13  81
# 	operon, input_transition, species operon:	6,2  14  1
# 	operon, input_transition, species operon:	7,1  15  56
# 	operon, input_transition, species operon:	7,1  15  8
# 	operon, input_transition, species operon:	7,1  16  3
# 	operon, input_transition, species operon:	7,1  16  81
# 	operon, input_transition, species operon:	7,2  17  1
# 	operon, input_transition, species operon:	8,1  18  56
# 	operon, input_transition, species operon:	8,1  18  8
# 	operon, input_transition, species operon:	8,1  19  14
# 	operon, input_transition, species operon:	8,1  19  2
# 	operon, input_transition, species operon:	8,2  20  1
# 	operon, input_transition, species operon:	9,1  21  14
# 	operon, input_transition, species operon:	9,1  21  2
# 	operon, input_transition, species operon:	9,1  22  3
# 	operon, input_transition, species operon:	9,1  22  81
# 	operon, input_transition, species operon:	9,2  23  1
# 	operon, input_transition, species operon:	10,1  24  56
# 	operon, input_transition, species operon:	10,1  24  8
# 	operon, input_transition, species operon:	10,1  25  3
# 	operon, input_transition, species operon:	10,1  25  81
# 	operon, input_transition, species operon:	10,2  26  1
# 	operon, input_transition, species operon:	12,1  27  28
# 	operon, input_transition, species operon:	13,1  28  28
# 	operon, input_transition, species operon:	14,1  29  28
# 	operon, input_transition, species operon:	15,1  30  26
# 	operon, input_transition, species operon:	15,1  30  27
# 	operon, input_transition, species operon:	16,1  31  56
# 	operon, input_transition, species operon:	16,1  31  8
# 	operon, input_transition, species operon:	17,1  32  28
# 	operon, input_transition, species operon:	18,1  33  26
# 	operon, input_transition, species operon:	18,1  33  27
# 	operon, input_transition, species operon:	18,2  34  28
# 	operon, input_transition, species operon:	19,1  35  28
# 	operon, input_transition, species operon:	19,2  36  26
# 	operon, input_transition, species operon:	19,2  36  27
# 	operon, input_transition, species operon:	20,1  37  56
# 	operon, input_transition, species operon:	20,1  37  8
# 	operon, input_transition, species operon:	20,2  38  26
# 	operon, input_transition, species operon:	20,2  38  27
# 	operon, input_transition, species operon:	21,1  39  26
# 	operon, input_transition, species operon:	21,1  39  27
# 	operon, input_transition, species operon:	21,2  40  28
# 	operon, input_transition, species operon:	22,1  41  56
# 	operon, input_transition, species operon:	22,1  41  8
# 	operon, input_transition, species operon:	22,2  42  26
# 	operon, input_transition, species operon:	22,2  42  27
# 	operon, input_transition, species operon:	23,1  43  26
# 	operon, input_transition, species operon:	23,1  43  38
# 	operon, input_transition, species operon:	23,2  44  1
# 	operon, input_transition, species operon:	24,1  45  1
# 	operon, input_transition, species operon:	24,2  46  14
# 	operon, input_transition, species operon:	24,2  46  2
# 	operon, input_transition, species operon:	25,1  47  1
# 	operon, input_transition, species operon:	25,2  48  21
# 	operon, input_transition, species operon:	25,2  48  9
# 	operon, input_transition, species operon:	28,1  49  1
# 	operon, input_transition, species operon:	28,2  50  21
# 	operon, input_transition, species operon:	28,2  50  9
# 	operon, input_transition, species operon:	29,1  51  26
# 	operon, input_transition, species operon:	29,1  51  38
# 	operon, input_transition, species operon:	29,2  52  28
# 	operon, input_transition, species operon:	29,3  53  1
# 	operon, input_transition, species operon:	31,1  54  50
# 	operon, input_transition, species operon:	31,1  54  51
# 	operon, input_transition, species operon:	31,2  55  28
# 	operon, input_transition, species operon:	33,1  56  79
# 	operon, input_transition, species operon:	33,2  57  1
# 	operon, input_transition, species operon:	35,1  58  14
# 	operon, input_transition, species operon:	35,1  58  2
# 	operon, input_transition, species operon:	35,2  59  1
# 	operon, input_transition, species operon:	37,1  60  14
# 	operon, input_transition, species operon:	37,1  60  2
# 	operon, input_transition, species operon:	37,2  61  1
# 	operon, input_transition, species operon:	39,1  62  6
# 	operon, input_transition, species operon:	39,1  62  7
# 	operon, input_transition, species operon:	39,2  63  93
# 	operon, input_transition, species operon:	44,1  64  21
# 	operon, input_transition, species operon:	44,1  64  9
# 	operon, input_transition, species operon:	44,2  65  28
# 	operon, input_transition, species operon:	46,1  66  21
# 	operon, input_transition, species operon:	46,1  66  9
# 	operon, input_transition, species operon:	46,2  67  26
# 	operon, input_transition, species operon:	46,2  67  27
# 	operon, input_transition, species operon:	46,3  68  1
# 	operon, input_transition, species operon:	47,1  69  21
# 	operon, input_transition, species operon:	47,1  69  9
# 	operon, input_transition, species operon:	47,2  70  21
# 	operon, input_transition, species operon:	47,2  70  27
# 	operon, input_transition, species operon:	47,3  71  1
# 	operon, input_transition, species operon:	48,1  72  26
# 	operon, input_transition, species operon:	48,1  72  27
# 	operon, input_transition, species operon:	48,2  73  1
# 	operon, input_transition, species operon:	49,1  74  26
# 	operon, input_transition, species operon:	49,1  74  27
# 	operon, input_transition, species operon:	49,2  75  1
# 	operon, input_transition, species operon:	50,1  76  26
# 	operon, input_transition, species operon:	50,1  76  27
# 	operon, input_transition, species operon:	50,1  77  14
# 	operon, input_transition, species operon:	50,1  77  2
# 	operon, input_transition, species operon:	51,1  78  26
# 	operon, input_transition, species operon:	51,1  78  27
# 	operon, input_transition, species operon:	51,1  79  14
# 	operon, input_transition, species operon:	51,1  79  2
# 	operon, input_transition, species operon:	52,1  80  56
# 	operon, input_transition, species operon:	52,1  80  8
# 	operon, input_transition, species operon:	54,1  81  24
# 	operon, input_transition, species operon:	54,1  81  95
# 	operon, input_transition, species operon:	54,3  82  24
# 	operon, input_transition, species operon:	54,3  83  21
# 	operon, input_transition, species operon:	54,3  83  9
# 	operon, input_transition, species operon:	55,2  84  21
# 	operon, input_transition, species operon:	55,2  84  24
# 	operon, input_transition, species operon:	55,2  84  9
# 	operon, input_transition, species operon:	55,2  85  1
# 	operon, input_transition, species operon:	55,3  86  24
# 	operon, input_transition, species operon:	55,3  86  95
# 	operon, input_transition, species operon:	56,1  87  21
# 	operon, input_transition, species operon:	56,1  87  24
# 	operon, input_transition, species operon:	56,1  88  28
# 	operon, input_transition, species operon:	56,2  89  24
# 	operon, input_transition, species operon:	56,2  89  95
# 	operon, input_transition, species operon:	56,3  90  56
# 	operon, input_transition, species operon:	56,3  90  8
# 	operon, input_transition, species operon:	57,1  91  26
# 	operon, input_transition, species operon:	57,1  91  27
# 	operon, input_transition, species operon:	57,1  92  14
# 	operon, input_transition, species operon:	57,1  92  2
# 	operon, input_transition, species operon:	69,1  93  1
# 	operon, input_transition, species operon:	69,2  94  10
# 	operon, input_transition, species operon:	69,2  94  9
# 	operon, input_transition, species operon:	71,1  95  1
# 	operon, input_transition, species operon:	71,2  96  56
# 	operon, input_transition, species operon:	71,2  96  8
# 	operon, input_transition, species operon:	72,1  97  1
# 	operon, input_transition, species operon:	72,2  98  56
# 	operon, input_transition, species operon:	72,2  98  8
# 	operon, input_transition, species operon:	72,3  99  26
# 	operon, input_transition, species operon:	72,3  99  27
# 	operon, input_transition, species operon:	73,1  100  28
# 	operon, input_transition, species operon:	73,2  101  26
# 	operon, input_transition, species operon:	73,2  101  27
# 	operon, input_transition, species operon:	73,3  102  56
# 	operon, input_transition, species operon:	73,3  102  8
# 	operon, input_transition, species operon:	73,4  103  1
# 	operon, input_transition, species operon:	74,1  104  14
# 	operon, input_transition, species operon:	74,1  104  2
# 	operon, input_transition, species operon:	74,2  105  1
# 	operon, input_transition, species operon:	75,1  106  14
# 	operon, input_transition, species operon:	75,1  106  2
# 	operon, input_transition, species operon:	75,2  107  1
# 	operon, input_transition, species operon:	76,1  108  14
# 	operon, input_transition, species operon:	76,1  108  2
# 	operon, input_transition, species operon:	76,2  109  1
# 	operon, input_transition, species operon:	77,1  110  26
# 	operon, input_transition, species operon:	77,1  110  27
# 	operon, input_transition, species operon:	77,2  111  14
# 	operon, input_transition, species operon:	77,2  111  2
# 	operon, input_transition, species operon:	78,1  112  54
# 	operon, input_transition, species operon:	78,1  113  17
# 	operon, input_transition, species operon:	78,1  113  60
# 	operon, input_transition, species operon:	78,2  114  1
# 	operon, input_transition, species operon:	79,1  115  14
# 	operon, input_transition, species operon:	79,1  115  2
# 	operon, input_transition, species operon:	79,2  116  28
# 	operon, input_transition, species operon:	79,3  117  1
# 	operon, input_transition, species operon:	80,1  118  26
# 	operon, input_transition, species operon:	80,1  118  27
# 	operon, input_transition, species operon:	80,2  119  28
# 	operon, input_transition, species operon:	80,3  120  1
# 	operon, input_transition, species operon:	81,1  121  26
# 	operon, input_transition, species operon:	81,1  121  27
# 	operon, input_transition, species operon:	81,2  122  28
# 	operon, input_transition, species operon:	81,3  123  1
# 	operon, input_transition, species operon:	82,1  124  26
# 	operon, input_transition, species operon:	82,1  124  27
# 	operon, input_transition, species operon:	82,2  125  1
# 	operon, input_transition, species operon:	88,1  126  14
# 	operon, input_transition, species operon:	88,1  126  2
# 	operon, input_transition, species operon:	88,2  127  1
# 	operon, input_transition, species operon:	89,1  128  26
# 	operon, input_transition, species operon:	89,1  128  27
# 	operon, input_transition, species operon:	89,2  129  1
# 	operon, input_transition, species operon:	90,1  130  21
# 	operon, input_transition, species operon:	90,1  130  9
# 	operon, input_transition, species operon:	90,2  131  1
# 	operon, input_transition, species operon:	91,1  132  56
# 	operon, input_transition, species operon:	91,1  132  8
# 	operon, input_transition, species operon:	91,2  133  1
# 	operon, input_transition, species operon:	92,1  134  56
# 	operon, input_transition, species operon:	92,1  134  8
# 	operon, input_transition, species operon:	92,2  135  1
# 	operon, input_transition, species operon:	93,1  136  14
# 	operon, input_transition, species operon:	93,1  136  2
# 	operon, input_transition, species operon:	93,2  137  1
# 	operon, input_transition, species operon:	94,1  138  4
# 	operon, input_transition, species operon:	94,1  138  5
# 	operon, input_transition, species operon:	95,1  139  56
# 	operon, input_transition, species operon:	95,1  139  8
# 	operon, input_transition, species operon:	95,2  140  1
# 	operon, input_transition, species operon:	96,1  141  14
# 	operon, input_transition, species operon:	96,1  141  2
# 	operon, input_transition, species operon:	96,2  142  1
# 	operon, input_transition, species operon:	97,1  143  45
# 	operon, input_transition, species operon:	97,1  143  46
# 	operon, input_transition, species operon:	98,1  144  56
# 	operon, input_transition, species operon:	98,1  144  8
# 	operon, input_transition, species operon:	98,2  145  1
# 	operon, input_transition, species operon:	99,1  146  21
# 	operon, input_transition, species operon:	99,1  146  9
# 	operon, input_transition, species operon:	99,2  147  1
# 	operon, input_transition, species operon:	100,1  148  29
# 	operon, input_transition, species operon:	100,1  148  39
# 	operon, input_transition, species operon:	101,1  149  29
# 	operon, input_transition, species operon:	101,1  149  39
# 	operon, input_transition, species operon:	101,2  150  56
# 	operon, input_transition, species operon:	101,2  150  8
# 	operon, input_transition, species operon:	101,3  151  21
# 	operon, input_transition, species operon:	101,3  151  9
# 	operon, input_transition, species operon:	101,4  152  1
# 	operon, input_transition, species operon:	101,5  153  1
# 	operon, input_transition, species operon:	102,1  154  45
# 	operon, input_transition, species operon:	102,1  154  46
# 	operon, input_transition, species operon:	102,2  155  14
# 	operon, input_transition, species operon:	102,2  155  2
# 	operon, input_transition, species operon:	102,3  156  26
# 	operon, input_transition, species operon:	102,3  156  27
# 	operon, input_transition, species operon:	102,4  157  1
# 	operon, input_transition, species operon:	102,5  158  1
# 	operon, input_transition, species operon:	103,1  159  26
# 	operon, input_transition, species operon:	103,1  159  27
# 	operon, input_transition, species operon:	104,1  160  21
# 	operon, input_transition, species operon:	104,1  160  9
# ({'19,2': [['26', '27']], '81,1': [['26', '27']], '81,3': [['1']], '19,1': [['28']], '51,1': [['26', '27'], ['14', '2']], '57,1': [['26', '27'], ['14', '2']], '90,1': [['21', '9']], '1,1': [['53', '9'], ['26', '27']], '81,2': [['28']], '79,1': [['14', '2']], '79,2': [['28']], '79,3': [['1']], '94,1': [['4', '5']], '5,2': [['1']], '5,1': [['14', '2'], ['56', '8']], '3,1': [['56', '8']], '3,2': [['1']], '77,2': [['14', '2']], '77,1': [['26', '27']], '46,2': [['26', '27']], '46,3': [['1']], '102,2': [['14', '2']], '46,1': [['21', '9']], '72,3': [['26', '27']], '72,2': [['56', '8']], '72,1': [['1']], '91,2': [['1']], '91,1': [['56', '8']], '21,2': [['28']], '21,1': [['26', '27']], '25,2': [['21', '9']], '25,1': [['1']], '37,2': [['1']], '104,1': [['21', '9']], '37,1': [['14', '2']], '31,1': [['50', '51']], '31,2': [['28']], '39,1': [['6', '7']], '39,2': [['93']], '95,2': [['1']], '95,1': [['56', '8']], '6,1': [['14', '2'], ['3', '81']], '80,1': [['26', '27']], '80,2': [['28']], '6,2': [['1']], '74,1': [['14', '2']], '74,2': [['1']], '16,1': [['56', '8']], '8,2': [['1']], '8,1': [['56', '8'], ['14', '2']], '92,1': [['56', '8']], '92,2': [['1']], '71,1': [['1']], '71,2': [['56', '8']], '75,1': [['14', '2']], '98,2': [['1']], '98,1': [['56', '8']], '75,2': [['1']], '101,1': [['29', '39']], '101,3': [['21', '9']], '15,1': [['26', '27']], '101,5': [['
    plasmid_name_input_species_name_dictionary = {}
    plasmid_name_output_species_name_dictionary = {}
    
    operon_id_plasmid_name_dictionary = {}
    
    species_id_to_name_dictionary = {}
    
    sql_cursor = sql.execute('SELECT spe_id,name FROM Species')
    
    for spe_id, spe_name in sql_cursor.fetchall():
        species_id_to_name_dictionary[spe_id] = spe_name

    input_operon_species_dictionary, output_operon_species_dictionary = make_traverse_input_output_dictionaries(sql)

    merged_ope_id_pla_name = sql.execute('''SELECT PlasmidOperon.ope_id,
                                                   Plasmid.name
                                            FROM PlasmidOperon,
                                                 Plasmid
                                            WHERE PlasmidOperon.pla_id = Plasmid.pla_id''')

    ###print merged_ope_id_pla_name.fetchall()

    for ope_id, pla_name in merged_ope_id_pla_name.fetchall():

        ###print "ope_id, pla_name:",ope_id," ", pla_name

        operon_id_plasmid_name_dictionary[ope_id] = pla_name

    ###for pair in operon_id_plasmid_name_dictionary.items():
        ###print pair
        
    for operon_id, species_id_list in input_operon_species_dictionary.items():
        
        ###print "species_id_list:", species_id_list
        
        extended_species_id_list = extend_list_of_lists(species_id_list)
        
        ###print "extended_species_id_list,",extended_species_id_list

        plasmid_name = operon_id_plasmid_name_dictionary[operon_id]
        
        ###print "spe_id entering sql dict and the type is", spe_id, type(spe_id)
        ###print "db_get_species_id(sql,spe_id):",db_get_species_id(sql,spe_id)
        
        #print "Is spe_id in species_id_to_name_dictionary:", spe_id in species_id_to_name_dictionary
        
        plasmid_name_input_species_name_dictionary[plasmid_name] = [db_get_species_name(sql,spe_id) for spe_id in extended_species_id_list]
        #plasmid_name_input_species_name_dictionary[plasmid_name] = [species_id_to_name_dictionary[spe_id] for spe_id in extended_species_id_list]

    print "Output Plasmid Loop"
    for operon_id, species_id_list in output_operon_species_dictionary.items():
        
        ###print "species_id_list:", species_id_list
        
        extended_species_id_list = extend_list_of_lists(species_id_list)
        
        ###print "extended_species_id_list:", extended_species_id_list
          
        plasmid_name = operon_id_plasmid_name_dictionary[operon_id]
        #spe_id = "'" + spe_id + "'"
        
        ###print "spe_id entering sql dict and the type is", spe_id, type(spe_id)
        ###print "db_get_species_id(sql,spe_id):",db_get_species_id(sql,spe_id)
        
        plasmid_name_input_species_name_dictionary[plasmid_name] = [db_get_species_name(sql,spe_id) for spe_id in extended_species_id_list]
        #plasmid_name_input_species_name_dictionary[plasmid_name] = [species_id_to_name_dictionary[spe_id] for spe_id in extended_species_id_list]
    return plasmid_name_input_species_name_dictionary,plasmid_name_output_species_name_dictionary

# %%
print make_pla_name_spe_name_dicts(cur)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-7c2216ee003c> in <module>()
# ----> 1 print make_pla_name_spe_name_dicts(cur)
#
# <ipython-input-51-c1373d0d2987> in make_pla_name_spe_name_dicts(sql)
#      13         species_id_to_name_dictionary[spe_id] = spe_name
#      14
# ---> 15     input_operon_species_dictionary, output_operon_species_dictionary = make_traverse_input_output_dictionaries(sql)
#      16
#      17     merged_ope_id_pla_name = sql.execute('''SELECT PlasmidOperon.ope_id,
#
# NameError: global name 'make_traverse_input_output_dictionaries' is not defined
